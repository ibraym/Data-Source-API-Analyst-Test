# %% [markdown]
# # GitHub Client Implementation

# %% [markdown]
# Required imports

# %%
import abc
from typing import Optional, Any, Dict, Union, List, Iterator, Tuple, ItemsView
from types import TracebackType
from typing_extensions import Self
import urllib
import json
import requests
from requests import Response
from requests.utils import get_encoding_from_headers
from requests.models import CaseInsensitiveDict
import urllib3
from urllib3.util import Retry
from urllib3.connectionpool import ConnectionPool
from urllib3.exceptions import MaxRetryError
from urllib3.response import HTTPResponse
import io
import time
from datetime import datetime, timezone

import logging
logger = logging.getLogger('my_logger')

logging.basicConfig()

# %% [markdown]
# Defining required constants

# %%
Consts = {
    'DEFAULT_BASE_URL': 'https://api.github.com',
    'DEFAULT_TIMEOUT': 15,
    'DEFAULT_USER_AGENT': 'Github API client by Github:@ibraym',
    'DEFAULT_PER_PAGE': 30,
    'DEFAULT_SECONDS_BETWEEN_REQUESTS': 1,
    'DEFAULT_SECONDARY_RATE_WAIT': 60,
    'headerRateRemaining': 'x-ratelimit-remaining',
    'headerRateLimit': 'x-ratelimit-limit',
    'headerRateReset': "X-RateLimit-Reset",
    'headerRawJSON': 'application/vnd.github.raw+json',
    'headerHtmlJSON': 'application/vnd.github.html+json',
    'headerObjectJSON': 'application/vnd.github.object+json',
}

# %% [markdown]
# Mimic the httplib connection and response objects by defining two class:
#    -  `RequestsResponse` class: it handles the response object to extract the status, headers and text fields. Also, it provides two methods to get the headers and read the response text.
#    - `HTTPSRequestsConnectionClass` class: It is a wrapper around the requests library in Python, designed to mimic the behavior of an httplib connection object. This class offers features like retries, connection pooling, and HTTPS connection management. It providers three methods:
#       - `request` method: It prepares a request with the specified HTTP method (verb), URL (url), body (input), and headers (headers).
#       - `getresponse` method: It executes the previously prepared HTTP request using the session object.
#       - `close` method: It closes the session, releasing any resources (e.g., connections in the pool).

# %%
class RequestsResponse:
    """
    A wrapper for `requests.Response` to mimic the `httplib` response object.

    Attributes:
        status (int): The HTTP status code of the response.
        headers (requests.structures.CaseInsensitiveDict): The headers of the response.
        text (str): The text content of the response.
    """
    def __init__(self, r: requests.Response):
        """
        Initializes the RequestsResponse object with the provided requests.Response.

        Args:
            r (requests.Response): The response object to wrap.
        """
        self.status = r.status_code
        self.headers = r.headers
        self.text = r.text

    def getheaders(self) -> ItemsView[str, str]:
        """
        Returns the headers of the response as an ItemsView.

        Returns:
            ItemsView[str, str]: The headers of the response.
        """
        return self.headers.items()

    def read(self) -> str:
        """
        Returns the text content of the response.

        Returns:
            str: The response body.
        """
        return self.text

def noopAuth(request: requests.models.PreparedRequest) -> requests.models.PreparedRequest:
    """
    A no-operation authentication handler for requests.

    Args:
        request (requests.models.PreparedRequest): The request object.

    Returns:
        requests.models.PreparedRequest: The unchanged request object.
    """
    return request

class HTTPSRequestsConnectionClass:
    retry: Union[int, Retry]

    """
    Mimics an `httplib` connection object using the `requests` library.

    Attributes:
        host (str): The target host for the connection.
        port (int): The port number for the connection (default is 443 for HTTPS).
        protocol (str): The protocol used, fixed to "https".
        timeout (Optional[int]): The timeout for requests, if any.
        verify (bool): Whether to verify SSL certificates (default is True).
        session (requests.Session): The requests session object used for connections.
        retry (Union[int, Retry]): The retry configuration for the HTTPAdapter.
        pool_size (int): The maximum number of connections for the pool.
    """
    def __init__(
        self,
        host: str,
        port: Optional[int] = None,
        strict: bool = False,
        timeout: Optional[int] = None,
        retry: Optional[Union[int, Retry]] = None,
        pool_size: Optional[int] = None,
        **kwargs: Any,
    ) -> None:
        """
        Initializes the HTTPSRequestsConnectionClass with the given configuration.

        Args:
            host (str): The target host for the connection.
            port (Optional[int]): The port for the connection. Defaults to 443.
            strict (bool): Unused parameter included for API compatibility.
            timeout (Optional[int]): The request timeout in seconds.
            retry (Optional[Union[int, Retry]]): Retry configuration or number of retries.
            pool_size (Optional[int]): The maximum size of the connection pool.
            **kwargs (Any): Additional arguments, such as SSL verification flags.
        """
        self.port = port if port else 443
        self.host = host
        self.protocol = "https"
        self.timeout = timeout
        self.verify = kwargs.get("verify", True)
        self.session = requests.Session()

        self.session.auth = noopAuth

        if retry is None:
            self.retry = requests.adapters.DEFAULT_RETRIES
        else:
            self.retry = retry

        if pool_size is None:
            self.pool_size = requests.adapters.DEFAULT_POOLSIZE
        else:
            self.pool_size = pool_size

        self.adapter = requests.adapters.HTTPAdapter(
            max_retries=self.retry,
            pool_connections=self.pool_size,
            pool_maxsize=self.pool_size,
        )
        self.session.mount("https://", self.adapter)

    def request(
        self,
        verb: str,
        url: str,
        input: Optional[Union[str, io.BufferedReader]],
        headers: Dict[str, str],
    ) -> None:
        """
        Prepares a request to be executed.

        Args:
            verb (str): The HTTP method (e.g., "GET", "POST").
            url (str): The URL path for the request.
            input (Optional[Union[str, io.BufferedReader]]): The request body, if any.
            headers (Dict[str, str]): The headers for the request.
        """
        self.verb = verb
        self.url = url
        self.input = input
        self.headers = headers

    def getresponse(self) -> RequestsResponse:
        """
        Executes the prepared request and returns the response.

        Returns:
            RequestsResponse: The wrapped response object.
        """
        verb = getattr(self.session, self.verb.lower())
        url = f"{self.protocol}://{self.host}:{self.port}{self.url}"
        r = verb(
            url,
            headers=self.headers,
            data=self.input,
            timeout=self.timeout,
            verify=self.verify,
            allow_redirects=False,
        )
        return RequestsResponse(r)

    def close(self) -> None:
        """
        Closes the session and cleans up resources.
        """
        self.session.close()

# %% [markdown]
# To handle authentication for HTTP requests. We use an abstract base class `Auth` to standardize the structure of authentication mechanisms, and a concrete implementation `Token` to provide authentication using a single, constant token.

# %%
class Auth(abc.ABC):
    """
    Base class of all authentication methods.
    """
    @property
    @abc.abstractmethod
    def token_type(self) -> str:
        """
        The type of the auth token, e.g. Bearer or Basic.

        :return: token type

        """
    @property
    @abc.abstractmethod
    def token(self) -> str:
        """
        The auth token as used in the HTTP Authorization header.

        :return: token

        """
    def authentication(self, headers: dict) -> None:
        """
        Add authorization to the headers.
        """
        headers["Authorization"] = f"{self.token_type} {self.token}"


class Token(Auth):
    """
    This class is used to authenticate with a single constant token.
    """

    def __init__(self, token: str):
        assert isinstance(token, str)
        assert len(token) > 0
        self._token = token

    @property
    def token_type(self) -> str:
        return "token"

    @property
    def token(self) -> str:
        return self._token

# %% [markdown]
# GithubRetry class is a Github-specific implementation of `urllib3.Retry`.
# Github requests are retry-able when the response provides a `"Retry-After"` header, or the content indicates a rate limit error.
#
# The class includes methods to distinguish between different types of rate-limit errors:
#    - `isRateLimitError`: Combines checks for both primary and secondary rate-limit errors.
#    - `isPrimaryRateLimitError`: Detects "API rate limit exceeded" errors in the response message.
#    - `isSecondaryRateLimitError`: Detects other messages associated with secondary rate limits, such as "please retry your request again later."
#
# Retry Logic: The `increment` method is overridden to handle retries when specific rate-limit conditions are encountered.
#    - Enhanced Error Handling:
#       - If the response status is 403, the method inspects the response for rate-limit messages or Retry-After headers.
#       - When a rate-limit error is detected:
#          - Primary Rate Limit: Uses the `X-RateLimit-Reset` header to determine how long to back off.
#          - Secondary Rate Limit: Uses `secondary_rate_wait` for backoff time.
#       - The calculated backoff is set for the next retry attempt using a custom `get_backoff_time`.
#    - Fallbacks: If no retry conditions are met, the method either raises an appropriate exception or proceeds with standard retry logic.

# %%
class GithubRetry(Retry):

    __datetime = datetime

    def __init__(self, secondary_rate_wait: float = Consts['DEFAULT_SECONDARY_RATE_WAIT'], **kwargs: Any) -> None:
        """
        :param secondary_rate_wait: seconds to wait before retrying secondary rate limit errors
        :param kwargs: see urllib3.Retry for more arguments
        """
        self.secondary_rate_wait = secondary_rate_wait
        kwargs["status_forcelist"] = kwargs.get("status_forcelist", list(range(500, 600))) + [403]
        kwargs["allowed_methods"] = kwargs.get("allowed_methods", Retry.DEFAULT_ALLOWED_METHODS.union({"GET", "POST"}))
        super().__init__(**kwargs)

    def new(self, **kw: Any) -> Self:
        kw.update(dict(secondary_rate_wait=self.secondary_rate_wait))
        return super().new(**kw)

    def isRateLimitError(self, message: str) -> bool:
        return self.isPrimaryRateLimitError(message) or self.isSecondaryRateLimitError(message)

    def isPrimaryRateLimitError(self, message: str) -> bool:
        if not message:
            return False

        message = message.lower()
        return message.startswith("api rate limit exceeded")

    def isSecondaryRateLimitError(self, message: str) -> bool:
        if not message:
            return False

        message = message.lower()
        return (
            message.startswith("you have exceeded a secondary rate limit")
            or message.endswith("please retry your request again later.")
            or message.endswith("please wait a few minutes before you try again.")
        )

    def increment(
        self,
        method: Optional[str] = None,
        url: Optional[str] = None,
        response: Optional[HTTPResponse] = None,
        error: Optional[Exception] = None,
        _pool: Optional[ConnectionPool] = None,
        _stacktrace: Optional[TracebackType] = None,
    ) -> Retry:
        if response:
            if response.status == 403:
                if "Retry-After" in response.headers:
                    # Sleeping 'Retry-After' seconds is implemented in urllib3.Retry.sleep() and called by urllib3
                    logger.info(f'Retrying after {response.headers.get("Retry-After")} seconds')
                else:
                    content = response.reason
                    # to identify retry-able methods, we inspect the response body
                    try:
                        content = self.get_content(response, url)  # type: ignore
                        content = json.loads(content)  # type: ignore
                        message = content.get("message")  # type: ignore
                    except Exception as e:
                        raise RuntimeError("Failed to inspect response message") from e

                    try:
                        if self.isRateLimitError(message):
                            rate_type = "primary" if self.isPrimaryRateLimitError(message) else "secondary"

                            # check early that we are retrying at all
                            retry = super().increment(method, url, response, error, _pool, _stacktrace)

                            # we backoff primary rate limit at least until X-RateLimit-Reset,
                            # we backoff secondary rate limit at for secondary_rate_wait seconds
                            backoff = 0.0

                            if self.isPrimaryRateLimitError(message):
                                if Consts['headerRateReset'] in response.headers:
                                    value = response.headers.get(Consts['headerRateReset'])
                                    if value and value.isdigit():
                                        reset = self.__datetime.fromtimestamp(int(value), timezone.utc)
                                        delta = reset - self.__datetime.now(timezone.utc)
                                        resetBackoff = delta.total_seconds()

                                        if resetBackoff > 0:
                                            logger.debug(f"Reset occurs in {str(delta)} ({value} / {reset})")

                                        # plus 1s as it is not clear when in that second the reset occurs
                                        backoff = resetBackoff + 1
                            else:
                                backoff = self.secondary_rate_wait

                            # we backoff at least retry's next backoff
                            retry_backoff = retry.get_backoff_time()
                            if retry_backoff > backoff:
                                if backoff > 0:
                                    logger.debug(
                                        f"Retry backoff of {retry_backoff}s exceeds "
                                        f"required rate limit backoff of {backoff}s".replace(".0s", "s"),
                                    )
                                backoff = retry_backoff

                            def get_backoff_time() -> float:
                                return backoff

                            logger.info(
                                f"Setting next backoff to {backoff}s".replace(".0s", "s"),
                            )
                            retry.get_backoff_time = get_backoff_time  # type: ignore
                            return retry

                        logger.debug(
                            "Response message does not indicate retry-able error",
                        )
                        raise Exception(f'{response.status} {content}')  # type: ignore
                    except MaxRetryError:
                        raise
                    except Exception as e:
                        raise RuntimeError("Failed to determine retry backoff") from e

                    raise Exception(f'{response.status} {content}')

        # retry the request as usual
        return super().increment(method, url, response, error, _pool, _stacktrace)

    @staticmethod
    def get_content(resp: HTTPResponse, url: str) -> bytes:
        # logic taken from HTTPAdapter.build_response (requests.adapters)
        response = Response()

        # Fallback to None if there's no status_code, for whatever reason.
        response.status_code = getattr(resp, "status", None)  # type: ignore

        # Make headers case-insensitive.
        response.headers = CaseInsensitiveDict(getattr(resp, "headers", {}))

        # Set encoding.
        response.encoding = get_encoding_from_headers(response.headers)
        response.raw = resp
        response.reason = response.raw.reason  # type: ignore

        response.url = url

        return response.content

# %% [markdown]
# Utility functions to manipulate URLs and parse HTTP headers, particularly for adding query parameters to URLs and extracting useful links from HTTP response headers.

# %%
def add_parameters_to_url(
    url: str,
    parameters: Dict[str, Any],
) -> str:
    """
    Add query parameters to a given URL.

    :param url: The base URL to which parameters will be added.
    :param parameters: A dictionary of parameters to add to the URL.
                       Existing parameters in the URL will be overwritten if they have the same keys.
    :return: The URL with the updated query parameters.
    """
    scheme, netloc, url, params, query, fragment = urllib.parse.urlparse(url)
    url_params = urllib.parse.parse_qs(query)
    # union parameters in url with given parameters, the latter have precedence
    url_params.update(**{k: v if isinstance(v, list) else [v] for k, v in parameters.items()})
    parameter_list = [(key, value) for key, values in url_params.items() for value in values]
    # remove query from url
    url = urllib.parse.urlunparse((scheme, netloc, url, params, "", fragment))

    if len(parameter_list) == 0:
        return url
    else:
        return f"{url}?{urllib.parse.urlencode(parameter_list)}"

def parseLinkHeader(headers: Dict[str, Union[str, int]]) -> Dict[str, str]:
    """
    Parse the `Link` header from HTTP response headers.

    :param headers: A dictionary containing HTTP response headers.
    :return: A dictionary mapping relation types (e.g., "next", "prev") to URLs.
    """
    links = {}
    if "link" in headers and isinstance(headers["link"], str):
        linkHeaders = headers["link"].split(", ")
        for linkHeader in linkHeaders:
            url, rel, *rest = linkHeader.split("; ")
            url = url[1:-1]
            rel = rel[5:-1]
            links[rel] = url
    return links

def is_iso_format(date_string):
    # Attempt to parse the string using the ISO 8601 format
    try:
        datetime.strptime(date_string, "%Y-%m-%dT%H:%M:%SZ")
        return True
    except ValueError:
        return False

# %% [markdown]
# The Github class provides a Python client to interact with the GitHub API v3, enabling authenticated access to endpoints, handling paginated responses, and enforcing API rate limits. It simplifies making API requests and managing authentication, retries, and response parsing.
#
# ## Documentation for the `Github` Class
#
# The `Github` class provides a Python client to interact with the GitHub API v3, enabling authenticated access to endpoints, handling paginated responses, and enforcing API rate limits. It simplifies making API requests and managing authentication, retries, and response parsing.
#
# ---
#
# ### **Constructor: `__init__`**
# Initializes a `Github` instance.
#
# #### Parameters:
# - **auth** (`Auth`): An `Auth` instance for API authentication.
# - **base_url** (`str`, optional): Base URL for the GitHub API. Default: `Consts['DEFAULT_BASE_URL']`.
# - **timeout** (`int`, optional): Timeout for API requests in seconds. Default: `Consts['DEFAULT_TIMEOUT']`.
# - **user_agent** (`str`, optional): User-agent string to identify the client. Default: `Consts['DEFAULT_USER_AGENT']`.
# - **per_page** (`int`, optional): Number of items per page for paginated responses. Default: `Consts['DEFAULT_PER_PAGE']`.
# - **verify** (`bool | str`, optional): SSL verification. Can be `True`, `False`, or a CA_BUNDLE file path.
# - **retry** (`int | Retry | None`, optional): Retry strategy for failed requests. Default: `default_retry`.
# - **seconds_between_requests** (`float | None`, optional): Delay between consecutive requests to prevent rate-limiting. Default: `Consts['DEFAULT_SECONDS_BETWEEN_REQUESTS']`.
#
# ---
#
# ### **Methods**
#
# #### **Private Methods**
#
# - **`__getConnection()`**
#   - Configures and returns an HTTPS connection object if not already initialized.
#   - Ensures proper retries, timeout, and SSL verification settings.
#
# - **`__deferRequest()`**
#   - Implements delay logic to enforce the minimum time interval between consecutive API requests.
#
# - **`__send_request(method, url, headers, input=None)`**
#   - Sends an HTTP request to the API.
#   - **Parameters**:
#     - `method` (`str`): HTTP method (e.g., "GET", "POST").
#     - `url` (`str`): Target URL.
#     - `headers` (`Dict[str, str]`): HTTP headers.
#     - `input` (`Optional[Any]`): Request body or payload.
#   - **Returns**: A tuple of HTTP status, response headers, and response content.
#
# - **`__makeAbsoluteUrl(url)`**
#   - Converts a relative URL to an absolute URL based on the base URL.
#
# - **`__check_response(status, responseHeaders, output)`**
#   - Validates the HTTP response and decodes JSON data if applicable.
#   - Raises an exception for errors (status codes >= 400).
#
# - **`__get(url, parameters=None, headers=None)`**
#   - Sends a `GET` request to the API.
#   - **Parameters**:
#     - `url` (`str`): Target URL.
#     - `parameters` (`Optional[Dict[str, Any]]`): Query parameters.
#     - `headers` (`Optional[Dict[str, str]]`): HTTP headers.
#   - **Returns**: A tuple of response headers and decoded response data.
#
# #### **Pagination Methods**
#
# - **`_getPage(data, headers)`**
#   - Extracts items from a paginated API response.
#   - Updates the `__nextUrl` for subsequent pagination requests.
#   - **Parameters**:
#     - `data` (`Any`): Response data.
#     - `headers` (`Optional[Dict[str, Union[str, int]]]`): HTTP headers containing pagination links.
#   - **Returns**: A list of items.
#
# - **`paginator(url, params=None, headers=None)`**
#   - Provides an iterator for paginated API results.
#   - **Parameters**:
#     - `url` (`str`): API endpoint URL.
#     - `params` (`Optional[Dict[str, Any]]`): Query parameters.
#     - `headers` (`Optional[Dict[str, Union[str, int]]]`): HTTP headers.
#   - **Yields**: Items from all paginated responses.
#
# #### **Public Methods**
#
# - **`close()`**
#   - Closes the connection to the API server.
#
# - **`search_repositories(query, sort=None, order=None, **qualifiers)`**
#   - Searches repositories using the GitHub API.
#   - **Parameters**:
#     - `query` (`str`): Search keywords.
#     - `sort` (`Optional[str]`): Sorting criteria (`'stars'`, `'forks'`, `'updated'`).
#     - `order` (`Optional[str]`): Sort order (`'asc'`, `'desc'`).
#     - `qualifiers` (`**kwargs`): Additional search qualifiers (e.g., language, topic).
#   - **Returns**: An iterator for repository search results.
#
# - **`commits(owner: str, repo: str, sha: Optional[str] = None, path: Optional[str] = None, author: Optional[str] = None, committer: Optional[str] = None, since: Optional[str] = None, until: Optional[str] = None)`**
#   - Retrieve a list of commits for a repository.
#   - **Parameters**:
#     - `owner`: GitHub username or organization owning the repository..
#     - `repo`: Repository name..
#     - `sha` (optional): Branch/commit SHA to start listing commits from.
#     - `path` (optional): Restrict results to commits affecting the specified file/directory.
#     - `author` (optional): Filter by author (username or email).
#     - `committer` (optional): Filter by committer (username or email).
#     - `since` (optional): ISO 8601 string to filter commits after a date.
#     - `until` (optional): ISO 8601 string to filter commits before a date.
#   - **Returns**: Iterator over commit objects.
#
# - **`contents(owner: str, repo: str, path: str, ref: Optional[str] = None, content_type: Optional[str] = None)`**
#   - Retrieve the content of a file or directory in a repository..
#   - **Parameters**:
#     - `owner`: GitHub username or organization owning the repository..
#     - `repo`: Repository name..
#     - `path`: File/directory path within the repository.
#     - `ref` (optional): Commit/branch/tag name (default: repo's default branch).
#     - `content_type` (optional): Desired response format ('raw', 'html', 'object').
#   - **Returns**: Iterator over dictionaries representing the file or directory contents, or raw content as a string.
#
# ---
#
# ### **Key Features**
# - **Authentication**: Integrates with the `Auth` class to handle token-based authentication.
# - **Rate Limit Management**: Tracks and enforces API rate limits to avoid throttling.
# - **Retry Strategy**: Handles retries for network errors and rate-limit responses.
# - **Pagination**: Simplifies handling of paginated API responses.
# - **Extensibility**: Designed for integration with additional API endpoints and functionalities.

# %%
default_retry = GithubRetry()

class Github:
    """
    The main class to access the GitHub API v3.
    Provides methods for performing authenticated API requests and managing paginated responses.
    """

    def __init__(
        self,
        auth: Auth,
        base_url: str = Consts['DEFAULT_BASE_URL'],
        timeout: int = Consts['DEFAULT_TIMEOUT'],
        user_agent: str = Consts['DEFAULT_USER_AGENT'],
        per_page: int = Consts['DEFAULT_PER_PAGE'],
        verify: bool | str = True,
        retry: int | Retry | None = default_retry,
        seconds_between_requests: float | None = Consts['DEFAULT_SECONDS_BETWEEN_REQUESTS'],
    )-> None:
        """
        Initialize the GitHub API client.

        :param auth: An instance of the `Auth` class for authentication.
        :param base_url: Base URL for GitHub API (defaults to `Consts['DEFAULT_BASE_URL']`).
        :param timeout: Timeout for API requests in seconds.
        :param user_agent: User agent string for the client.
        :param per_page: Number of items per page for paginated responses.
        :param verify: SSL verification (can be `True`, `False`, or a path to a CA_BUNDLE file).
        :param retry: Retry configuration, either an integer or a `Retry` object.
        :param seconds_between_requests: Minimum delay between requests to avoid rate-limiting.
        """
        assert isinstance(auth, Auth), auth
        assert isinstance(timeout, int), timeout
        assert user_agent is None or isinstance(user_agent, str), user_agent
        assert isinstance(per_page, int), per_page
        assert isinstance(verify, (bool, str)), verify
        assert retry is None or isinstance(retry, int) or isinstance(retry, urllib3.util.Retry), retry
        assert seconds_between_requests is None or seconds_between_requests >= 0

        self.__auth = auth
        self.__base_url = base_url

        o = urllib.parse.urlparse(base_url)
        assert o.scheme == 'https'
        self.__hostname = o.hostname
        self.__port = o.port
        self.__prefix = o.path

        self.__timeout = timeout
        self.__retry = retry
        self.__seconds_between_requests = seconds_between_requests
        self.__connection = None

        self.rate_limiting = (-1, -1)
        self.rate_limiting_resettime = 0
        self.per_page = per_page

        assert user_agent is not None # github now requires a user-agent.
        self.__userAgent = user_agent
        self.__verify = verify
        self.__last_requests: Dict[str, float] = dict()

    def __getConnection(self):
        """
        Create and configure the HTTP connection object if it does not already exist.

        :return: Configured HTTPS connection object.
        """
        if self.__connection is not None:
            return self.__connection

        return HTTPSRequestsConnectionClass(
            self.__hostname,
            self.__port,
            retry=self.__retry,
            timeout=self.__timeout,
            verify=self.__verify,
        )

    def __deferRequest(self) -> None:
        """
        Enforce a delay between consecutive requests to respect the API's rate limits.
        """
        requests = self.__last_requests.values()

        last_request = max(requests) if requests else 0

        next_request = (last_request + self.__seconds_between_requests) if self.__seconds_between_requests else 0

        defer = max(next_request - datetime.now(timezone.utc).timestamp(), 0)
        time.sleep(defer)

    def __send_request(
        self,
        method: str,
        url: str,
        headers: Dict[str, str],
        input: Optional[Any] = None,
    ):
        """
        Send an HTTP request using the configured connection.

        :param method: HTTP method (e.g., "GET", "POST").
        :param url: The target URL for the request.
        :param headers: Dictionary of HTTP headers for the request.
        :param input: Optional payload or body for the request.
        :return: Tuple containing status, response headers, and response content.
        """
        self.__deferRequest()

        try:
            self.__connection = self.__getConnection()

            self.__connection.request(method, url, input, headers)
            response = self.__connection.getresponse()

            status = response.status
            responseHeaders = {k.lower(): v for k, v in response.getheaders()}
            output = response.read()

            return status, responseHeaders, output
        finally:
            self.__last_requests[method] = datetime.now(timezone.utc).timestamp()

    def __makeAbsoluteUrl(self, url: str) -> str:
        """
        Convert a relative URL to an absolute URL based on the base URL.

        :param url: Relative or absolute URL.
        :return: Fully qualified absolute URL.
        """
        if url.startswith("/"):
            url = f"{self.__prefix}{url}"
        else:
            o = urllib.parse.urlparse(url)
            assert o.hostname in [
                self.__hostname,
                "uploads.github.com",
                "status.github.com",
                "github.com",
            ], o.hostname
            assert o.path.startswith((self.__prefix, "/api/", "/login/oauth")), o.path
            assert o.port == self.__port, o.port
            url = o.path
            if o.query != "":
                url += f"?{o.query}"
        return url

    def __check_response(
        self,
        status: int,
        responseHeaders: Dict[str, Any],
        output: str,
    ) -> Tuple[Dict[str, Any], Any]:
        """
        Check the API response for errors and decode the response content.

        :param status: HTTP status code.
        :param responseHeaders: Dictionary of HTTP response headers.
        :param output: Raw response content.
        :return: Decoded response data (JSON if applicable).
        """
        data = output
        is_JSON = False
        if isinstance(output, bytes):
            data = output.decode('utf-8')
        if status >= 400:
            raise Exception(f'{status} {data}')
        if 'content-type' in responseHeaders:
            if Consts['headerRawJSON'] in responseHeaders['content-type'] or \
               Consts['headerHtmlJSON'] in responseHeaders['content-type']:
                return responseHeaders, data
        if len(data) == 0:
            return None
        else:
            try:
                data = json.loads(data)
            except ValueError:
                raise
        return responseHeaders, data


    def __get(self,
        url: str,
        parameters: Optional[Dict[str, Any]] = None,
        headers: Optional[Dict[str, str]] = None,
    ) -> Tuple[Dict[str, Any], Any]:
        """
        Perform a GET request to the GitHub API.

        :param url: Target URL for the request.
        :param parameters: Optional query parameters for the request.
        :param headers: Optional HTTP headers for the request.
        :return: Tuple containing response headers and data.
        """
        if parameters is None:
            parameters = {}
        if headers is None:
            headers = {}
        if self.__auth is not None:
            self.__auth.authentication(headers)
        headers['User-Agent'] = self.__userAgent

        url = self.__makeAbsoluteUrl(url)
        url = add_parameters_to_url(url, parameters)

        status, responseHeaders, output = self.__send_request('get', url, headers)

        if Consts['headerRateRemaining'] in responseHeaders and Consts['headerRateLimit'] in responseHeaders:
            self.rate_limiting = (
                int(float(responseHeaders[Consts['headerRateRemaining']])),
                int(float(responseHeaders[Consts['headerRateLimit']])),
            )
        if Consts['headerRateReset'] in responseHeaders:
            self.rate_limiting_resettime = int(float(responseHeaders[Consts['headerRateReset']]))

        return self.__check_response(status, responseHeaders, output)

    def paginator(self,
            url: str,
            params: Optional[Dict[str, Any]] = None,
            headers: Optional[Dict[str, Union[str, int]]] = None) -> Iterator[Dict] | str:
        """
        Create a generator to iterate over paginated results.

        :param url: API endpoint URL.
        :param params: Query parameters for the request.
        :param headers: HTTP headers for the request.
        :return: Iterator yielding items from all pages.
        """
        nextParams: Dict[str, Any] = params or {}
        nextUrl = url
        if self.per_page != 30:
            nextParams['per_page'] = self.per_page
        while nextUrl is not None:
            headers, data = self.__get(nextUrl, nextParams, headers)
            if 'content-type' in headers:
                if Consts['headerRawJSON'] in headers['content-type'] or \
                    Consts['headerHtmlJSON'] in headers['content-type']:
                    content = data
                    yield content
            data = data if data else []
            nextUrl = None
            if len(data) > 0:
                links = parseLinkHeader(headers)
                if "next" in links:
                    nextUrl = links["next"]
            nextParams = {}
            if 'items' in data:
                totalCount = data.get('total_count')
                data = data['items']
            content = [
                element
                for element in data
                if element is not None
            ]
            yield from content


    def close(self) -> None:
        """
        Close the API client's connection to the server.
        """
        self.__connection.close()

    def search_repositories(
        self,
        query: str,
        sort: Optional[str] = None,
        order: Optional[str] = None,
        qualifiers: Optional[Dict] = None,
    ) -> Iterator[Dict]:
        """
        :calls: `GET /search/repositories <https://docs.github.com/en/rest/reference/search>`
        :param query: string
        :param sort: string ('stars', 'forks', 'updated')
        :param order: string ('asc', 'desc')
        :param qualifiers: dict query qualifiers
        """
        assert isinstance(query, str), query
        url_parameters = dict()
        if sort is not None:
            assert sort in ("stars", "forks", "updated"), sort
            url_parameters["sort"] = sort
        if order is not None:
            assert order in ("asc", "desc"), order
            url_parameters["order"] = order

        query_chunks = []
        if query:
            query_chunks.append(query)

        for qualifier, value in qualifiers.items():
            query_chunks.append(f"{qualifier}:{value}")

        url_parameters["q"] = " ".join(query_chunks)
        assert url_parameters["q"], "need at least one qualifier"

        return self.paginator(
            "/search/repositories",
            url_parameters,
        )

    def commits(
        self,
        owner: str,
        repo: str,
        sha: Optional[str] = None,
        path: Optional[str] = None,
        author: Optional[str] = None,
        committer: Optional[str] = None,
        since: Optional[str] = None,
        until: Optional[str] = None,
    ) -> Iterator[Dict]:
        """
        Retrieve a list of commits for a repository.

        :param owner: The GitHub username or organization that owns the repository.
        :param repo: The name of the repository.
        :param sha: Optional. The SHA or branch to start listing commits from.
        :param path: Optional. Restrict results to commits that affect the specified file or directory path.
        :param author: Optional. Filter commits by a specific author, using their GitHub username or email address.
        :param committer: Optional. Filter commits by a specific committer, using their GitHub username or email address.
        :param since: Optional. ISO 8601 date string to filter commits after the specified date.
        :param until: Optional. ISO 8601 date string to filter commits before the specified date.
        :return: An iterator over dictionaries, where each dictionary represents a commit object.

        **Example Usage:**

        ```python
        commits = github.commits(
            owner="octocat",
            repo="Hello-World",
            sha="main",
            since="2023-01-01T00:00:00Z",
            until="2023-12-31T23:59:59Z",
        )
        for commit in commits:
            print(commit["sha"])
        ```

        **Filters:**
        - `sha`: Retrieves commits starting from a specific branch or commit.
        - `path`: Limits the results to a specific file or directory.
        - `author` / `committer`: Filters results based on the author's or committer's identity.
        - `since` / `until`: Limits the results to a specific time range using ISO 8601 date strings (e.g., `"2023-01-01T00:00:00Z"`).

        **Notes:**
        - Ensure `since` and `until` are valid ISO 8601 date strings.
        - The method returns an iterator, so it efficiently handles paginated responses from the GitHub API.
        """
        assert isinstance(owner, str), owner
        assert isinstance(repo, str), repo
        url_parameters = dict()
        if sha is not None:
            assert isinstance(sha, str), sha
            url_parameters["sha"] = sha
        if path is not None:
            assert isinstance(path, str), path
            url_parameters["path"] = path
        if author is not None:
            assert isinstance(author, str), author
            url_parameters["author"] = author
        if committer is not None:
            assert isinstance(committer, str), committer
            url_parameters["committer"] = committer
        if since is not None:
            assert isinstance(since, str) and is_iso_format(since), since
            url_parameters["since"] = since
        if until is not None:
            assert isinstance(until, str) and is_iso_format(until), until
            url_parameters["until"] = until
        return self.paginator(
            f"/repos/{owner}/{repo}/commits",
            url_parameters,
        )

    def contents(
        self,
        owner: str,
        repo: str,
        path: str,
        ref: Optional[str] = None,
        content_type: Optional[str] = None,
    ) -> Iterator[Dict] | str:
        """
        Retrieve the content of a file or directory in a repository.

        :param owner: The GitHub username or organization that owns the repository.
        :param repo: The name of the repository.
        :param path: The path to the file or directory within the repository.
        :param ref: Optional. The name of the commit/branch/tag. Defaults to the repository's default branch (usually `main`).
        :param content_type: Optional. Specifies the format of the returned content.
                            Must be one of `'raw'`, `'html'`, or `'object'`.
                            - `'raw'`: Returns raw content.
                            - `'html'`: Returns content rendered as HTML.
                            - `'object'`: Returns a JSON representation of the object.
        :return: An iterator over dictionaries, where each dictionary represents the content of the specified path.

        **Notes:**
        - The `path` parameter can refer to either a file or a directory.
        - If `ref` is not provided, the method retrieves content from the repository's default branch.
        - Use `content_type` to control how the content is returned (raw bytes, HTML, or JSON object).
        - This method supports paginated responses for directories containing multiple items.

        **Headers:**
        - If `content_type` is specified, custom `Accept` headers are added to define the desired response format.
        - For `'raw'`, the header `application/vnd.github.raw` is used.
        - For `'html'`, the header `application/vnd.github.html` is used.
        - For `'object'`, the header `application/vnd.github.object` is used.
        """
        assert isinstance(owner, str), owner
        assert isinstance(repo, str), repo
        assert isinstance(path, str), path
        url_parameters = dict()
        if ref is not None:
            assert isinstance(ref, str), ref
            url_parameters["ref"] = ref
        headers: Optional[Dict[str, str]] = None
        if content_type is not None:
            assert content_type in ['raw', 'html', 'object'], content_type
            if content_type == 'raw':
                headers = {'Accept': Consts['headerRawJSON']}
            if content_type == 'html':
                headers = {'Accept': Consts['headerHtmlJSON']}
            if content_type == 'object':
                headers = {'Accept': Consts['headerObjectJSON']}

        return self.paginator(
            f"/repos/{owner}/{repo}/contents/{path}",
            url_parameters,
            headers=headers,
        )

# %% [markdown]
# # Data extraction examples:

# %% [markdown]
# ### Adding an access token

# %%
# using an access token
ACCESS_TOKEN = 'YOUR_API_KEY_HERE'
auth = Token(ACCESS_TOKEN)

# %% [markdown]
# ### Defining the client

# %%
# First create a Github instance:
g = Github(auth=auth)

# %% [markdown]
# ### Search repositories

# %%
# We will search for repositories that contains `OpenAI` in its readme file and has more than 10000 followers
repos = g.search_repositories(query='OpenAI', qualifiers={'in':'readme', 'followers': '>=10000'})
for repo in repos:
    print(repo)
# Out:
# {'id': 599394820, 'node_id': 'R_kgDOI7oKBA', 'name': 'chatgpt-web', 'full_name': 'Chanzhaoyu/chatgpt-web', 'private': False, 'owner': {'login': 'Chanzhaoyu', 'id': 24789441, 'node_id': 'MDQ6VXNlcjI0Nzg5NDQx', 'avatar_url': 'https://avatars.githubusercontent.com/u/24789441?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Chanzhaoyu', 'html_url': 'https://github.com/Chanzhaoyu', 'followers_url': 'https://api.github.com/users/Chanzhaoyu/followers', 'following_url': 'https://api.github.com/users/Chanzhaoyu/following{/other_user}', 'gists_url': 'https://api.github.com/users/Chanzhaoyu/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Chanzhaoyu/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Chanzhaoyu/subscriptions', 'organizations_url': 'https://api.github.com/users/Chanzhaoyu/orgs', 'repos_url': 'https://api.github.com/users/Chanzhaoyu/repos', 'events_url': 'https://api.github.com/users/Chanzhaoyu/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Chanzhaoyu/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/Chanzhaoyu/chatgpt-web', 'description': '用 Express 和  Vue3 搭建的 ChatGPT 演示网页', 'fork': False, 'url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web', 'forks_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/forks', 'keys_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/teams', 'hooks_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/hooks', 'issue_events_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/issues/events{/number}', 'events_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/events', 'assignees_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/assignees{/user}', 'branches_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/branches{/branch}', 'tags_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/tags', 'blobs_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/languages', 'stargazers_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/stargazers', 'contributors_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/contributors', 'subscribers_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/subscribers', 'subscription_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/subscription', 'commits_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/contents/{+path}', 'compare_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/merges', 'archive_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/downloads', 'issues_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/issues{/number}', 'pulls_url': 'https://api.github.com/repos/Chanzhaoyu/chatgpt-web/pulls{/number}', 'milestones_url': 'https://api ...
# {'id': 468576060, 'node_id': 'R_kgDOG-3nPA', 'name': 'openai-cookbook', 'full_name': 'openai/openai-cookbook', 'private': False, 'owner': {'login': 'openai', 'id': 14957082, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE0OTU3MDgy', 'avatar_url': 'https://avatars.githubusercontent.com/u/14957082?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/openai', 'html_url': 'https://github.com/openai', 'followers_url': 'https://api.github.com/users/openai/followers', 'following_url': 'https://api.github.com/users/openai/following{/other_user}', 'gists_url': 'https://api.github.com/users/openai/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/openai/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/openai/subscriptions', 'organizations_url': 'https://api.github.com/users/openai/orgs', 'repos_url': 'https://api.github.com/users/openai/repos', 'events_url': 'https://api.github.com/users/openai/events{/privacy}', 'received_events_url': 'https://api.github.com/users/openai/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/openai/openai-cookbook', 'description': 'Examples and guides for using the OpenAI API', 'fork': False, 'url': 'https://api.github.com/repos/openai/openai-cookbook', 'forks_url': 'https://api.github.com/repos/openai/openai-cookbook/forks', 'keys_url': 'https://api.github.com/repos/openai/openai-cookbook/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/openai/openai-cookbook/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/openai/openai-cookbook/teams', 'hooks_url': 'https://api.github.com/repos/openai/openai-cookbook/hooks', 'issue_events_url': 'https://api.github.com/repos/openai/openai-cookbook/issues/events{/number}', 'events_url': 'https://api.github.com/repos/openai/openai-cookbook/events', 'assignees_url': 'https://api.github.com/repos/openai/openai-cookbook/assignees{/user}', 'branches_url': 'https://api.github.com/repos/openai/openai-cookbook/branches{/branch}', 'tags_url': 'https://api.github.com/repos/openai/openai-cookbook/tags', 'blobs_url': 'https://api.github.com/repos/openai/openai-cookbook/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/openai/openai-cookbook/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/openai/openai-cookbook/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/openai/openai-cookbook/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/openai/openai-cookbook/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/openai/openai-cookbook/languages', 'stargazers_url': 'https://api.github.com/repos/openai/openai-cookbook/stargazers', 'contributors_url': 'https://api.github.com/repos/openai/openai-cookbook/contributors', 'subscribers_url': 'https://api.github.com/repos/openai/openai-cookbook/subscribers', 'subscription_url': 'https://api.github.com/repos/openai/openai-cookbook/subscription', 'commits_url': 'https://api.github.com/repos/openai/openai-cookbook/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/openai/openai-cookbook/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/openai/openai-cookbook/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/openai/openai-cookbook/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/openai/openai-cookbook/contents/{+path}', 'compare_url': 'https://api.github.com/repos/openai/openai-cookbook/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/openai/openai-cookbook/merges', 'archive_url': 'https://api.github.com/repos/openai/openai-cookbook/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/openai/openai-cookbook/downloads', 'issues_url': 'https://api.github.com/repos/openai/openai-cookbook/issues{/number}', 'pulls_url': 'https://api.github.com/repos/openai/openai-cookbook/pulls{/number}', 'milestones_url': 'https://api.github.com/re ...
# {'id': 655806940, 'node_id': 'R_kgDOJxbR3A', 'name': 'generative-ai-for-beginners', 'full_name': 'microsoft/generative-ai-for-beginners', 'private': False, 'owner': {'login': 'microsoft', 'id': 6154722, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNTQ3MjI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/microsoft', 'html_url': 'https://github.com/microsoft', 'followers_url': 'https://api.github.com/users/microsoft/followers', 'following_url': 'https://api.github.com/users/microsoft/following{/other_user}', 'gists_url': 'https://api.github.com/users/microsoft/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/microsoft/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/microsoft/subscriptions', 'organizations_url': 'https://api.github.com/users/microsoft/orgs', 'repos_url': 'https://api.github.com/users/microsoft/repos', 'events_url': 'https://api.github.com/users/microsoft/events{/privacy}', 'received_events_url': 'https://api.github.com/users/microsoft/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/microsoft/generative-ai-for-beginners', 'description': '21 Lessons, Get Started Building with Generative AI  🔗 https://microsoft.github.io/generative-ai-for-beginners/', 'fork': False, 'url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners', 'forks_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/forks', 'keys_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/teams', 'hooks_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/hooks', 'issue_events_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/issues/events{/number}', 'events_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/events', 'assignees_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/assignees{/user}', 'branches_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/branches{/branch}', 'tags_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/tags', 'blobs_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/languages', 'stargazers_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/stargazers', 'contributors_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/contributors', 'subscribers_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/subscribers', 'subscription_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/subscription', 'commits_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/microsoft/generative-ai-for-beginners/contents/{+path}', 'compare_url': 'https:// ...
# {'id': 307213173, 'node_id': 'MDEwOlJlcG9zaXRvcnkzMDcyMTMxNzM=', 'name': 'openai-python', 'full_name': 'openai/openai-python', 'private': False, 'owner': {'login': 'openai', 'id': 14957082, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE0OTU3MDgy', 'avatar_url': 'https://avatars.githubusercontent.com/u/14957082?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/openai', 'html_url': 'https://github.com/openai', 'followers_url': 'https://api.github.com/users/openai/followers', 'following_url': 'https://api.github.com/users/openai/following{/other_user}', 'gists_url': 'https://api.github.com/users/openai/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/openai/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/openai/subscriptions', 'organizations_url': 'https://api.github.com/users/openai/orgs', 'repos_url': 'https://api.github.com/users/openai/repos', 'events_url': 'https://api.github.com/users/openai/events{/privacy}', 'received_events_url': 'https://api.github.com/users/openai/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/openai/openai-python', 'description': 'The official Python library for the OpenAI API', 'fork': False, 'url': 'https://api.github.com/repos/openai/openai-python', 'forks_url': 'https://api.github.com/repos/openai/openai-python/forks', 'keys_url': 'https://api.github.com/repos/openai/openai-python/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/openai/openai-python/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/openai/openai-python/teams', 'hooks_url': 'https://api.github.com/repos/openai/openai-python/hooks', 'issue_events_url': 'https://api.github.com/repos/openai/openai-python/issues/events{/number}', 'events_url': 'https://api.github.com/repos/openai/openai-python/events', 'assignees_url': 'https://api.github.com/repos/openai/openai-python/assignees{/user}', 'branches_url': 'https://api.github.com/repos/openai/openai-python/branches{/branch}', 'tags_url': 'https://api.github.com/repos/openai/openai-python/tags', 'blobs_url': 'https://api.github.com/repos/openai/openai-python/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/openai/openai-python/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/openai/openai-python/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/openai/openai-python/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/openai/openai-python/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/openai/openai-python/languages', 'stargazers_url': 'https://api.github.com/repos/openai/openai-python/stargazers', 'contributors_url': 'https://api.github.com/repos/openai/openai-python/contributors', 'subscribers_url': 'https://api.github.com/repos/openai/openai-python/subscribers', 'subscription_url': 'https://api.github.com/repos/openai/openai-python/subscription', 'commits_url': 'https://api.github.com/repos/openai/openai-python/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/openai/openai-python/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/openai/openai-python/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/openai/openai-python/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/openai/openai-python/contents/{+path}', 'compare_url': 'https://api.github.com/repos/openai/openai-python/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/openai/openai-python/merges', 'archive_url': 'https://api.github.com/repos/openai/openai-python/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/openai/openai-python/downloads', 'issues_url': 'https://api.github.com/repos/openai/openai-python/issues{/number}', 'pulls_url': 'https://api.github.com/repos/openai/openai-python/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/openai/openai-python/milestones{/number}', ' ...
# {'id': 718741813, 'node_id': 'R_kgDOKtchNQ', 'name': 'screenshot-to-code', 'full_name': 'abi/screenshot-to-code', 'private': False, 'owner': {'login': 'abi', 'id': 23818, 'node_id': 'MDQ6VXNlcjIzODE4', 'avatar_url': 'https://avatars.githubusercontent.com/u/23818?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/abi', 'html_url': 'https://github.com/abi', 'followers_url': 'https://api.github.com/users/abi/followers', 'following_url': 'https://api.github.com/users/abi/following{/other_user}', 'gists_url': 'https://api.github.com/users/abi/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/abi/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/abi/subscriptions', 'organizations_url': 'https://api.github.com/users/abi/orgs', 'repos_url': 'https://api.github.com/users/abi/repos', 'events_url': 'https://api.github.com/users/abi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/abi/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/abi/screenshot-to-code', 'description': 'Drop in a screenshot and convert it to clean code (HTML/Tailwind/React/Vue)', 'fork': False, 'url': 'https://api.github.com/repos/abi/screenshot-to-code', 'forks_url': 'https://api.github.com/repos/abi/screenshot-to-code/forks', 'keys_url': 'https://api.github.com/repos/abi/screenshot-to-code/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/abi/screenshot-to-code/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/abi/screenshot-to-code/teams', 'hooks_url': 'https://api.github.com/repos/abi/screenshot-to-code/hooks', 'issue_events_url': 'https://api.github.com/repos/abi/screenshot-to-code/issues/events{/number}', 'events_url': 'https://api.github.com/repos/abi/screenshot-to-code/events', 'assignees_url': 'https://api.github.com/repos/abi/screenshot-to-code/assignees{/user}', 'branches_url': 'https://api.github.com/repos/abi/screenshot-to-code/branches{/branch}', 'tags_url': 'https://api.github.com/repos/abi/screenshot-to-code/tags', 'blobs_url': 'https://api.github.com/repos/abi/screenshot-to-code/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/abi/screenshot-to-code/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/abi/screenshot-to-code/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/abi/screenshot-to-code/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/abi/screenshot-to-code/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/abi/screenshot-to-code/languages', 'stargazers_url': 'https://api.github.com/repos/abi/screenshot-to-code/stargazers', 'contributors_url': 'https://api.github.com/repos/abi/screenshot-to-code/contributors', 'subscribers_url': 'https://api.github.com/repos/abi/screenshot-to-code/subscribers', 'subscription_url': 'https://api.github.com/repos/abi/screenshot-to-code/subscription', 'commits_url': 'https://api.github.com/repos/abi/screenshot-to-code/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/abi/screenshot-to-code/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/abi/screenshot-to-code/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/abi/screenshot-to-code/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/abi/screenshot-to-code/contents/{+path}', 'compare_url': 'https://api.github.com/repos/abi/screenshot-to-code/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/abi/screenshot-to-code/merges', 'archive_url': 'https://api.github.com/repos/abi/screenshot-to-code/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/abi/screenshot-to-code/downloads', 'issues_url': 'https://api.github.com/repos/abi/screenshot-to-code/issues{/number}', 'pulls_url': 'https://api.github.com/repos/abi/screenshot-to-code/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/abi/screenshot-to-code/miles ...
# {'id': 762304524, 'node_id': 'R_kgDOLW_YDA', 'name': 'composio', 'full_name': 'ComposioHQ/composio', 'private': False, 'owner': {'login': 'ComposioHQ', 'id': 128464815, 'node_id': 'O_kgDOB6g3rw', 'avatar_url': 'https://avatars.githubusercontent.com/u/128464815?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ComposioHQ', 'html_url': 'https://github.com/ComposioHQ', 'followers_url': 'https://api.github.com/users/ComposioHQ/followers', 'following_url': 'https://api.github.com/users/ComposioHQ/following{/other_user}', 'gists_url': 'https://api.github.com/users/ComposioHQ/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ComposioHQ/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ComposioHQ/subscriptions', 'organizations_url': 'https://api.github.com/users/ComposioHQ/orgs', 'repos_url': 'https://api.github.com/users/ComposioHQ/repos', 'events_url': 'https://api.github.com/users/ComposioHQ/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ComposioHQ/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/ComposioHQ/composio', 'description': "Composio equip's your AI agents & LLMs with 100+ high-quality integrations via function calling", 'fork': False, 'url': 'https://api.github.com/repos/ComposioHQ/composio', 'forks_url': 'https://api.github.com/repos/ComposioHQ/composio/forks', 'keys_url': 'https://api.github.com/repos/ComposioHQ/composio/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ComposioHQ/composio/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ComposioHQ/composio/teams', 'hooks_url': 'https://api.github.com/repos/ComposioHQ/composio/hooks', 'issue_events_url': 'https://api.github.com/repos/ComposioHQ/composio/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ComposioHQ/composio/events', 'assignees_url': 'https://api.github.com/repos/ComposioHQ/composio/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ComposioHQ/composio/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ComposioHQ/composio/tags', 'blobs_url': 'https://api.github.com/repos/ComposioHQ/composio/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ComposioHQ/composio/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ComposioHQ/composio/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ComposioHQ/composio/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ComposioHQ/composio/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ComposioHQ/composio/languages', 'stargazers_url': 'https://api.github.com/repos/ComposioHQ/composio/stargazers', 'contributors_url': 'https://api.github.com/repos/ComposioHQ/composio/contributors', 'subscribers_url': 'https://api.github.com/repos/ComposioHQ/composio/subscribers', 'subscription_url': 'https://api.github.com/repos/ComposioHQ/composio/subscription', 'commits_url': 'https://api.github.com/repos/ComposioHQ/composio/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ComposioHQ/composio/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ComposioHQ/composio/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ComposioHQ/composio/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ComposioHQ/composio/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ComposioHQ/composio/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ComposioHQ/composio/merges', 'archive_url': 'https://api.github.com/repos/ComposioHQ/composio/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ComposioHQ/composio/downloads', 'issues_url': 'https://api.github.com/repos/ComposioHQ/composio/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ComposioHQ/composio/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ComposioHQ/composio/mile ...
# {'id': 609416865, 'node_id': 'R_kgDOJFL2oQ', 'name': 'openai-translator', 'full_name': 'openai-translator/openai-translator', 'private': False, 'owner': {'login': 'openai-translator', 'id': 133774696, 'node_id': 'O_kgDOB_k9aA', 'avatar_url': 'https://avatars.githubusercontent.com/u/133774696?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/openai-translator', 'html_url': 'https://github.com/openai-translator', 'followers_url': 'https://api.github.com/users/openai-translator/followers', 'following_url': 'https://api.github.com/users/openai-translator/following{/other_user}', 'gists_url': 'https://api.github.com/users/openai-translator/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/openai-translator/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/openai-translator/subscriptions', 'organizations_url': 'https://api.github.com/users/openai-translator/orgs', 'repos_url': 'https://api.github.com/users/openai-translator/repos', 'events_url': 'https://api.github.com/users/openai-translator/events{/privacy}', 'received_events_url': 'https://api.github.com/users/openai-translator/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/openai-translator/openai-translator', 'description': '基于 ChatGPT API 的划词翻译浏览器插件和跨平台桌面端应用    -    Browser extension and cross-platform desktop application for translation based on ChatGPT API.', 'fork': False, 'url': 'https://api.github.com/repos/openai-translator/openai-translator', 'forks_url': 'https://api.github.com/repos/openai-translator/openai-translator/forks', 'keys_url': 'https://api.github.com/repos/openai-translator/openai-translator/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/openai-translator/openai-translator/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/openai-translator/openai-translator/teams', 'hooks_url': 'https://api.github.com/repos/openai-translator/openai-translator/hooks', 'issue_events_url': 'https://api.github.com/repos/openai-translator/openai-translator/issues/events{/number}', 'events_url': 'https://api.github.com/repos/openai-translator/openai-translator/events', 'assignees_url': 'https://api.github.com/repos/openai-translator/openai-translator/assignees{/user}', 'branches_url': 'https://api.github.com/repos/openai-translator/openai-translator/branches{/branch}', 'tags_url': 'https://api.github.com/repos/openai-translator/openai-translator/tags', 'blobs_url': 'https://api.github.com/repos/openai-translator/openai-translator/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/openai-translator/openai-translator/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/openai-translator/openai-translator/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/openai-translator/openai-translator/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/openai-translator/openai-translator/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/openai-translator/openai-translator/languages', 'stargazers_url': 'https://api.github.com/repos/openai-translator/openai-translator/stargazers', 'contributors_url': 'https://api.github.com/repos/openai-translator/openai-translator/contributors', 'subscribers_url': 'https://api.github.com/repos/openai-translator/openai-translator/subscribers', 'subscription_url': 'https://api.github.com/repos/openai-translator/openai-translator/subscription', 'commits_url': 'https://api.github.com/repos/openai-translator/openai-translator/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/openai-translator/openai-translator/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/openai-translator/openai-translator/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/openai-translator/openai-translator/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/openai-translator/openai-translator/con ...
# {'id': 573819845, 'node_id': 'R_kgDOIjPLxQ', 'name': 'ChatGPT', 'full_name': 'acheong08/ChatGPT', 'private': False, 'owner': {'login': 'acheong08', 'id': 36258159, 'node_id': 'MDQ6VXNlcjM2MjU4MTU5', 'avatar_url': 'https://avatars.githubusercontent.com/u/36258159?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/acheong08', 'html_url': 'https://github.com/acheong08', 'followers_url': 'https://api.github.com/users/acheong08/followers', 'following_url': 'https://api.github.com/users/acheong08/following{/other_user}', 'gists_url': 'https://api.github.com/users/acheong08/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/acheong08/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/acheong08/subscriptions', 'organizations_url': 'https://api.github.com/users/acheong08/orgs', 'repos_url': 'https://api.github.com/users/acheong08/repos', 'events_url': 'https://api.github.com/users/acheong08/events{/privacy}', 'received_events_url': 'https://api.github.com/users/acheong08/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/acheong08/ChatGPT', 'description': 'Reverse engineered ChatGPT API', 'fork': False, 'url': 'https://api.github.com/repos/acheong08/ChatGPT', 'forks_url': 'https://api.github.com/repos/acheong08/ChatGPT/forks', 'keys_url': 'https://api.github.com/repos/acheong08/ChatGPT/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/acheong08/ChatGPT/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/acheong08/ChatGPT/teams', 'hooks_url': 'https://api.github.com/repos/acheong08/ChatGPT/hooks', 'issue_events_url': 'https://api.github.com/repos/acheong08/ChatGPT/issues/events{/number}', 'events_url': 'https://api.github.com/repos/acheong08/ChatGPT/events', 'assignees_url': 'https://api.github.com/repos/acheong08/ChatGPT/assignees{/user}', 'branches_url': 'https://api.github.com/repos/acheong08/ChatGPT/branches{/branch}', 'tags_url': 'https://api.github.com/repos/acheong08/ChatGPT/tags', 'blobs_url': 'https://api.github.com/repos/acheong08/ChatGPT/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/acheong08/ChatGPT/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/acheong08/ChatGPT/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/acheong08/ChatGPT/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/acheong08/ChatGPT/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/acheong08/ChatGPT/languages', 'stargazers_url': 'https://api.github.com/repos/acheong08/ChatGPT/stargazers', 'contributors_url': 'https://api.github.com/repos/acheong08/ChatGPT/contributors', 'subscribers_url': 'https://api.github.com/repos/acheong08/ChatGPT/subscribers', 'subscription_url': 'https://api.github.com/repos/acheong08/ChatGPT/subscription', 'commits_url': 'https://api.github.com/repos/acheong08/ChatGPT/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/acheong08/ChatGPT/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/acheong08/ChatGPT/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/acheong08/ChatGPT/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/acheong08/ChatGPT/contents/{+path}', 'compare_url': 'https://api.github.com/repos/acheong08/ChatGPT/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/acheong08/ChatGPT/merges', 'archive_url': 'https://api.github.com/repos/acheong08/ChatGPT/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/acheong08/ChatGPT/downloads', 'issues_url': 'https://api.github.com/repos/acheong08/ChatGPT/issues{/number}', 'pulls_url': 'https://api.github.com/repos/acheong08/ChatGPT/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/acheong08/ChatGPT/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/acheong08/ChatGPT/notifications{?since,all,participating}', 'labels_url': 'https: ...
# {'id': 612344730, 'node_id': 'R_kgDOJH-jmg', 'name': 'ChatGPT-Next-Web', 'full_name': 'ChatGPTNextWeb/ChatGPT-Next-Web', 'private': False, 'owner': {'login': 'ChatGPTNextWeb', 'id': 153288546, 'node_id': 'O_kgDOCSL_Yg', 'avatar_url': 'https://avatars.githubusercontent.com/u/153288546?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ChatGPTNextWeb', 'html_url': 'https://github.com/ChatGPTNextWeb', 'followers_url': 'https://api.github.com/users/ChatGPTNextWeb/followers', 'following_url': 'https://api.github.com/users/ChatGPTNextWeb/following{/other_user}', 'gists_url': 'https://api.github.com/users/ChatGPTNextWeb/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ChatGPTNextWeb/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ChatGPTNextWeb/subscriptions', 'organizations_url': 'https://api.github.com/users/ChatGPTNextWeb/orgs', 'repos_url': 'https://api.github.com/users/ChatGPTNextWeb/repos', 'events_url': 'https://api.github.com/users/ChatGPTNextWeb/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ChatGPTNextWeb/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/ChatGPTNextWeb/ChatGPT-Next-Web', 'description': 'A cross-platform ChatGPT/Gemini UI (Web / PWA / Linux / Win / MacOS). 一键拥有你自己的跨平台 ChatGPT/Gemini 应用。', 'fork': False, 'url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web', 'forks_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/forks', 'keys_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/teams', 'hooks_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/hooks', 'issue_events_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/events', 'assignees_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/tags', 'blobs_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/languages', 'stargazers_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/stargazers', 'contributors_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/contributors', 'subscribers_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/subscribers', 'subscription_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/subscription', 'commits_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT-Next-Web/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ChatGPTNextWeb/ChatGPT- ...
# {'id': 600596928, 'node_id': 'R_kgDOI8xhwA', 'name': 'LibreChat', 'full_name': 'danny-avila/LibreChat', 'private': False, 'owner': {'login': 'danny-avila', 'id': 110412045, 'node_id': 'U_kgDOBpTBDQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/110412045?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/danny-avila', 'html_url': 'https://github.com/danny-avila', 'followers_url': 'https://api.github.com/users/danny-avila/followers', 'following_url': 'https://api.github.com/users/danny-avila/following{/other_user}', 'gists_url': 'https://api.github.com/users/danny-avila/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/danny-avila/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/danny-avila/subscriptions', 'organizations_url': 'https://api.github.com/users/danny-avila/orgs', 'repos_url': 'https://api.github.com/users/danny-avila/repos', 'events_url': 'https://api.github.com/users/danny-avila/events{/privacy}', 'received_events_url': 'https://api.github.com/users/danny-avila/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/danny-avila/LibreChat', 'description': 'Enhanced ChatGPT Clone: Features Anthropic, AWS, OpenAI, Assistants API, Azure, Groq, o1, GPT-4o, Mistral, OpenRouter, Vertex AI, Gemini, Artifacts, AI model switching, message search, langchain, DALL-E-3, ChatGPT Plugins, OpenAI Functions, Secure Multi-User System, Presets, completely open-source for self-hosting. Actively in public development.', 'fork': False, 'url': 'https://api.github.com/repos/danny-avila/LibreChat', 'forks_url': 'https://api.github.com/repos/danny-avila/LibreChat/forks', 'keys_url': 'https://api.github.com/repos/danny-avila/LibreChat/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/danny-avila/LibreChat/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/danny-avila/LibreChat/teams', 'hooks_url': 'https://api.github.com/repos/danny-avila/LibreChat/hooks', 'issue_events_url': 'https://api.github.com/repos/danny-avila/LibreChat/issues/events{/number}', 'events_url': 'https://api.github.com/repos/danny-avila/LibreChat/events', 'assignees_url': 'https://api.github.com/repos/danny-avila/LibreChat/assignees{/user}', 'branches_url': 'https://api.github.com/repos/danny-avila/LibreChat/branches{/branch}', 'tags_url': 'https://api.github.com/repos/danny-avila/LibreChat/tags', 'blobs_url': 'https://api.github.com/repos/danny-avila/LibreChat/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/danny-avila/LibreChat/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/danny-avila/LibreChat/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/danny-avila/LibreChat/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/danny-avila/LibreChat/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/danny-avila/LibreChat/languages', 'stargazers_url': 'https://api.github.com/repos/danny-avila/LibreChat/stargazers', 'contributors_url': 'https://api.github.com/repos/danny-avila/LibreChat/contributors', 'subscribers_url': 'https://api.github.com/repos/danny-avila/LibreChat/subscribers', 'subscription_url': 'https://api.github.com/repos/danny-avila/LibreChat/subscription', 'commits_url': 'https://api.github.com/repos/danny-avila/LibreChat/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/danny-avila/LibreChat/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/danny-avila/LibreChat/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/danny-avila/LibreChat/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/danny-avila/LibreChat/contents/{+path}', 'compare_url': 'https://api.github.com/repos/danny-avila/LibreChat/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/danny-avila/LibreChat/merges', 'archive_url': 'https://api.github.com/repos/danny-avila/LibreChat/{archive_format}{/ ...
# {'id': 575340621, 'node_id': 'R_kgDOIksATQ', 'name': 'ChatGPT', 'full_name': 'lencx/ChatGPT', 'private': False, 'owner': {'login': 'lencx', 'id': 16164244, 'node_id': 'MDQ6VXNlcjE2MTY0MjQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/16164244?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lencx', 'html_url': 'https://github.com/lencx', 'followers_url': 'https://api.github.com/users/lencx/followers', 'following_url': 'https://api.github.com/users/lencx/following{/other_user}', 'gists_url': 'https://api.github.com/users/lencx/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lencx/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lencx/subscriptions', 'organizations_url': 'https://api.github.com/users/lencx/orgs', 'repos_url': 'https://api.github.com/users/lencx/repos', 'events_url': 'https://api.github.com/users/lencx/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lencx/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/lencx/ChatGPT', 'description': '🔮 ChatGPT Desktop Application (Mac, Windows and Linux)', 'fork': False, 'url': 'https://api.github.com/repos/lencx/ChatGPT', 'forks_url': 'https://api.github.com/repos/lencx/ChatGPT/forks', 'keys_url': 'https://api.github.com/repos/lencx/ChatGPT/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/lencx/ChatGPT/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/lencx/ChatGPT/teams', 'hooks_url': 'https://api.github.com/repos/lencx/ChatGPT/hooks', 'issue_events_url': 'https://api.github.com/repos/lencx/ChatGPT/issues/events{/number}', 'events_url': 'https://api.github.com/repos/lencx/ChatGPT/events', 'assignees_url': 'https://api.github.com/repos/lencx/ChatGPT/assignees{/user}', 'branches_url': 'https://api.github.com/repos/lencx/ChatGPT/branches{/branch}', 'tags_url': 'https://api.github.com/repos/lencx/ChatGPT/tags', 'blobs_url': 'https://api.github.com/repos/lencx/ChatGPT/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/lencx/ChatGPT/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/lencx/ChatGPT/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/lencx/ChatGPT/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/lencx/ChatGPT/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/lencx/ChatGPT/languages', 'stargazers_url': 'https://api.github.com/repos/lencx/ChatGPT/stargazers', 'contributors_url': 'https://api.github.com/repos/lencx/ChatGPT/contributors', 'subscribers_url': 'https://api.github.com/repos/lencx/ChatGPT/subscribers', 'subscription_url': 'https://api.github.com/repos/lencx/ChatGPT/subscription', 'commits_url': 'https://api.github.com/repos/lencx/ChatGPT/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/lencx/ChatGPT/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/lencx/ChatGPT/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/lencx/ChatGPT/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/lencx/ChatGPT/contents/{+path}', 'compare_url': 'https://api.github.com/repos/lencx/ChatGPT/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/lencx/ChatGPT/merges', 'archive_url': 'https://api.github.com/repos/lencx/ChatGPT/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/lencx/ChatGPT/downloads', 'issues_url': 'https://api.github.com/repos/lencx/ChatGPT/issues{/number}', 'pulls_url': 'https://api.github.com/repos/lencx/ChatGPT/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/lencx/ChatGPT/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/lencx/ChatGPT/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/lencx/ChatGPT/labels{/name}', 'releases_url': 'https://api.github.com/repos/lencx/ChatGPT/releases{/id}', 'deployments_url': 'https://api.github. ...
# ...
# {'id': 121010586, 'node_id': 'MDEwOlJlcG9zaXRvcnkxMjEwMTA1ODY=', 'name': 'TelegramGroup', 'full_name': 'AZeC4/TelegramGroup', 'private': False, 'owner': {'login': 'AZeC4', 'id': 28788674, 'node_id': 'MDQ6VXNlcjI4Nzg4Njc0', 'avatar_url': 'https://avatars.githubusercontent.com/u/28788674?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/AZeC4', 'html_url': 'https://github.com/AZeC4', 'followers_url': 'https://api.github.com/users/AZeC4/followers', 'following_url': 'https://api.github.com/users/AZeC4/following{/other_user}', 'gists_url': 'https://api.github.com/users/AZeC4/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/AZeC4/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/AZeC4/subscriptions', 'organizations_url': 'https://api.github.com/users/AZeC4/orgs', 'repos_url': 'https://api.github.com/users/AZeC4/repos', 'events_url': 'https://api.github.com/users/AZeC4/events{/privacy}', 'received_events_url': 'https://api.github.com/users/AZeC4/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/AZeC4/TelegramGroup', 'description': '2024最新悄咪咪收集的10000+个Telegram群合集，附全网最有趣好用的机器人BOT🤖【电报百科全书】', 'fork': False, 'url': 'https://api.github.com/repos/AZeC4/TelegramGroup', 'forks_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/forks', 'keys_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/teams', 'hooks_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/hooks', 'issue_events_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/issues/events{/number}', 'events_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/events', 'assignees_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/assignees{/user}', 'branches_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/branches{/branch}', 'tags_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/tags', 'blobs_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/languages', 'stargazers_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/stargazers', 'contributors_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/contributors', 'subscribers_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/subscribers', 'subscription_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/subscription', 'commits_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/contents/{+path}', 'compare_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/merges', 'archive_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/downloads', 'issues_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/issues{/number}', 'pulls_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/AZeC4/TelegramGroup/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/AZeC4/Te ...
# {'id': 24878875, 'node_id': 'MDEwOlJlcG9zaXRvcnkyNDg3ODg3NQ==', 'name': 'awesome-zsh-plugins', 'full_name': 'unixorn/awesome-zsh-plugins', 'private': False, 'owner': {'login': 'unixorn', 'id': 23920, 'node_id': 'MDQ6VXNlcjIzOTIw', 'avatar_url': 'https://avatars.githubusercontent.com/u/23920?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/unixorn', 'html_url': 'https://github.com/unixorn', 'followers_url': 'https://api.github.com/users/unixorn/followers', 'following_url': 'https://api.github.com/users/unixorn/following{/other_user}', 'gists_url': 'https://api.github.com/users/unixorn/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/unixorn/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/unixorn/subscriptions', 'organizations_url': 'https://api.github.com/users/unixorn/orgs', 'repos_url': 'https://api.github.com/users/unixorn/repos', 'events_url': 'https://api.github.com/users/unixorn/events{/privacy}', 'received_events_url': 'https://api.github.com/users/unixorn/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/unixorn/awesome-zsh-plugins', 'description': 'A collection of ZSH frameworks, plugins, themes and tutorials.', 'fork': False, 'url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins', 'forks_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/forks', 'keys_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/teams', 'hooks_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/hooks', 'issue_events_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/issues/events{/number}', 'events_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/events', 'assignees_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/assignees{/user}', 'branches_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/branches{/branch}', 'tags_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/tags', 'blobs_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/languages', 'stargazers_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/stargazers', 'contributors_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/contributors', 'subscribers_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/subscribers', 'subscription_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/subscription', 'commits_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/contents/{+path}', 'compare_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/merges', 'archive_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/unixorn/awesome-zsh-plugins/downloads', 'issues_url': 'https://api.gi ...
# {'id': 32484381, 'node_id': 'MDEwOlJlcG9zaXRvcnkzMjQ4NDM4MQ==', 'name': 'free-for-dev', 'full_name': 'ripienaar/free-for-dev', 'private': False, 'owner': {'login': 'ripienaar', 'id': 82342, 'node_id': 'MDQ6VXNlcjgyMzQy', 'avatar_url': 'https://avatars.githubusercontent.com/u/82342?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ripienaar', 'html_url': 'https://github.com/ripienaar', 'followers_url': 'https://api.github.com/users/ripienaar/followers', 'following_url': 'https://api.github.com/users/ripienaar/following{/other_user}', 'gists_url': 'https://api.github.com/users/ripienaar/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ripienaar/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ripienaar/subscriptions', 'organizations_url': 'https://api.github.com/users/ripienaar/orgs', 'repos_url': 'https://api.github.com/users/ripienaar/repos', 'events_url': 'https://api.github.com/users/ripienaar/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ripienaar/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/ripienaar/free-for-dev', 'description': 'A list of SaaS, PaaS and IaaS offerings that have free tiers of interest to devops and infradev', 'fork': False, 'url': 'https://api.github.com/repos/ripienaar/free-for-dev', 'forks_url': 'https://api.github.com/repos/ripienaar/free-for-dev/forks', 'keys_url': 'https://api.github.com/repos/ripienaar/free-for-dev/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ripienaar/free-for-dev/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ripienaar/free-for-dev/teams', 'hooks_url': 'https://api.github.com/repos/ripienaar/free-for-dev/hooks', 'issue_events_url': 'https://api.github.com/repos/ripienaar/free-for-dev/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ripienaar/free-for-dev/events', 'assignees_url': 'https://api.github.com/repos/ripienaar/free-for-dev/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ripienaar/free-for-dev/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ripienaar/free-for-dev/tags', 'blobs_url': 'https://api.github.com/repos/ripienaar/free-for-dev/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ripienaar/free-for-dev/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ripienaar/free-for-dev/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ripienaar/free-for-dev/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ripienaar/free-for-dev/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ripienaar/free-for-dev/languages', 'stargazers_url': 'https://api.github.com/repos/ripienaar/free-for-dev/stargazers', 'contributors_url': 'https://api.github.com/repos/ripienaar/free-for-dev/contributors', 'subscribers_url': 'https://api.github.com/repos/ripienaar/free-for-dev/subscribers', 'subscription_url': 'https://api.github.com/repos/ripienaar/free-for-dev/subscription', 'commits_url': 'https://api.github.com/repos/ripienaar/free-for-dev/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ripienaar/free-for-dev/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ripienaar/free-for-dev/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ripienaar/free-for-dev/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ripienaar/free-for-dev/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ripienaar/free-for-dev/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ripienaar/free-for-dev/merges', 'archive_url': 'https://api.github.com/repos/ripienaar/free-for-dev/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ripienaar/free-for-dev/downloads', 'issues_url': 'https://api.github.com/repos/ripienaar/free-for-dev/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ripienaar/f ...

# %% [markdown]
# ### List commits

# %%
# List up to 10 commits from official Linux kernel repo
owner = 'torvalds'
repo = 'linux'
commits = g.commits(owner=owner, repo=repo)
count = 0
for commit in commits:
    if count > 10:
        break
    print(commit)
    count += 1
# Out:
# {'sha': '7eef7e306d3c40a0c5b9ff6adc9b273cc894dbd5', 'node_id': 'C_kwDOACN7MtoAKDdlZWY3ZTMwNmQzYzQwYTBjNWI5ZmY2YWRjOWIyNzNjYzg5NGRiZDU', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T02:54:00Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T02:54:00Z'}, 'message': 'Merge tag \'for-6.13/dm-changes\' of git://git.kernel.org/pub/scm/linux/kernel/git/device-mapper/linux-dm\n\nPull device mapper updates from Mikulas Patocka:\n\n - remove unused functions and variables\n\n - rate-limit error messages in syslog\n\n - fix typo\n\n - remove u64 alignment requirement for murmurhash\n\n - reset bi_ioprio to the default for dm-vdo\n\n - add support for get_unique_id\n\n - Add missing destroy_work_on_stack() to dm-thin\n\n - use kmalloc to allocate power-of-two sized buffers in bufio\n\n* tag \'for-6.13/dm-changes\' of git://git.kernel.org/pub/scm/linux/kernel/git/device-mapper/linux-dm:\n  dm-verity: remove the unused "data_start" variable\n  dm-bufio: use kmalloc to allocate power-of-two sized buffers\n  dm thin: Add missing destroy_work_on_stack()\n  dm: add support for get_unique_id\n  dm vdo: fix function doc comment formatting\n  dm vdo int-map: remove unused parameters\n  dm-vdo: reset bi_ioprio to the default value when the bio is reset\n  dm-vdo murmurhash: remove u64 alignment requirement\n  dm: Fix typo in error message\n  dm ioctl: rate limit a couple of ioctl based error messages\n  dm vdo: Remove unused uds_compute_index_size\n  dm vdo: Remove unused functions\n  dm: zoned: Remove unused functions\n  dm: Remove unused dm_table_bio_based\n  dm: Remove unused dm_set_md_type\n  dm cache: Remove unused functions in bio-prison-v1\n  dm cache: Remove unused dm_cache_size\n  dm cache: Remove unused dm_cache_dump\n  dm cache: Remove unused btracker_nr_writebacks_queued', 'tree': {'sha': 'ab3ce390a1c92de0c78cadccf534c1eba9a0a474', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/ab3ce390a1c92de0c78cadccf534c1eba9a0a474'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/7eef7e306d3c40a0c5b9ff6adc9b273cc894dbd5', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/7eef7e306d3c40a0c5b9ff6adc9b273cc894dbd5', 'html_url': 'https://github.com/torvalds/linux/commit/7eef7e306d3c40a0c5b9ff6adc9b273cc894dbd5', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/7eef7e306d3c40a0c5b9ff6adc9b273cc894dbd5/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'committer': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/u ...
# {'sha': '0637a68b9c6c1dfffcc1fca003cb7cd3257c3c03', 'node_id': 'C_kwDOACN7MtoAKDA2MzdhNjhiOWM2YzFkZmZmY2MxZmNhMDAzY2I3Y2QzMjU3YzNjMDM', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T02:50:55Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T02:50:55Z'}, 'message': 'Merge tag \'scsi-misc\' of git://git.kernel.org/pub/scm/linux/kernel/git/jejb/scsi\n\nPull SCSI updates from James Bottomley:\n "Updates to the usual drivers (ufs, lpfc, hisi_sas, st).\n\n  Amazingly enough, no core changes with the biggest set of driver\n  changes being ufs (which conflicted with it\'s own fixes a bit, hence\n  the merges) and the rest being minor fixes and updates"\n\n* tag \'scsi-misc\' of git://git.kernel.org/pub/scm/linux/kernel/git/jejb/scsi: (97 commits)\n  scsi: st: New session only when Unit Attention for new tape\n  scsi: st: Add MTIOCGET and MTLOAD to ioctls allowed after device reset\n  scsi: st: Don\'t modify unknown block number in MTIOCGET\n  scsi: ufs: core: Restore SM8650 support\n  scsi: sun3: Mark driver struct with __refdata to prevent section mismatch\n  scsi: sg: Enable runtime power management\n  scsi: qedi: Fix a possible memory leak in qedi_alloc_and_init_sb()\n  scsi: qedf: Fix a possible memory leak in qedf_alloc_and_init_sb()\n  scsi: fusion: Remove unused variable \'rc\'\n  scsi: bfa: Fix use-after-free in bfad_im_module_exit()\n  scsi: esas2r: Remove unused esas2r_build_cli_req()\n  scsi: target: Fix incorrect function name in pscsi_create_type_disk()\n  scsi: ufs: Replace deprecated PCI functions\n  scsi: Switch back to struct platform_driver::remove()\n  scsi: pm8001: Increase request sg length to support 4MiB requests\n  scsi: pm8001: Initialize devices in pm8001_alloc_dev()\n  scsi: pm8001: Use module param to set pcs event log severity\n  scsi: ufs: ufs-mediatek: Configure individual LU queue flags\n  scsi: MAINTAINERS: Update UFS Exynos entry\n  scsi: lpfc: Copyright updates for 14.4.0.6 patches\n  ...', 'tree': {'sha': 'e7d9a7accb6335c46ac3a6ce77860bd55eca839c', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/e7d9a7accb6335c46ac3a6ce77860bd55eca839c'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/0637a68b9c6c1dfffcc1fca003cb7cd3257c3c03', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/0637a68b9c6c1dfffcc1fca003cb7cd3257c3c03', 'html_url': 'https://github.com/torvalds/linux/commit/0637a68b9c6c1dfffcc1fca003cb7cd3257c3c03', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/0637a68b9c6c1dfffcc1fca003cb7cd3257c3c03/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'committer': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds ...
# {'sha': '222974c6ec9d901f7ad13bbe6e505ec1f1d822d4', 'node_id': 'C_kwDOACN7MtoAKDIyMjk3NGM2ZWM5ZDkwMWY3YWQxM2JiZTZlNTA1ZWMxZjFkODIyZDQ', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T02:45:33Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T02:45:33Z'}, 'message': 'iommu: remove stale declaration left over by a merge conflict\n\nThe merge commit ae3325f752ef ("Merge branches \'arm/smmu\', \'mediatek\',\n\'s390\', \'ti/omap\', \'riscv\' and \'core\' into next") left a stale\ndeclaration of \'iommu_present()\' even though the \'core\' branch that was\nmerged had removed the function (and the declaration).\n\nRemove it for real.\n\nReported-by: Dmitry Safonov <0x7f454c46@gmail.com>\nCc: Joerg Roedel <jroedel@suse.de>\nSigned-off-by: Linus Torvalds <torvalds@linux-foundation.org>', 'tree': {'sha': '41a05482263e3b0b09d880ea677c068444b172fa', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/41a05482263e3b0b09d880ea677c068444b172fa'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/222974c6ec9d901f7ad13bbe6e505ec1f1d822d4', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/222974c6ec9d901f7ad13bbe6e505ec1f1d822d4', 'html_url': 'https://github.com/torvalds/linux/commit/222974c6ec9d901f7ad13bbe6e505ec1f1d822d4', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/222974c6ec9d901f7ad13bbe6e505ec1f1d822d4/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'committer': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'parents': [{'sha': '78a2cbd809ef834b680f2825d3e4c16ec66f8ffa', 'url': 'https://api.github.com/repos/torvalds/linux/commits/78a2cbd809ef834b680f2825d3e4c16ec66f8ffa', 'html_url': 'https://github.com/torvalds/linux/commit/78a2cbd809ef834b680f2825d3e4c16ec66f8ffa'}]}
# {'sha': '78a2cbd809ef834b680f2825d3e4c16ec66f8ffa', 'node_id': 'C_kwDOACN7MtoAKDc4YTJjYmQ4MDllZjgzNGI2ODBmMjgyNWQzZTRjMTZlYzY2ZjhmZmE', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T02:31:48Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T02:31:48Z'}, 'message': 'Merge tag \'libnvdimm-for-6.13\' of git://git.kernel.org/pub/scm/linux/kernel/git/nvdimm/nvdimm\n\nPull nvdimm and DAX updates from Ira Weiny:\n "Most represent minor cleanups and code removals. One patch fixes\n  potential NULL pointer arithmetic which was benign because the offset\n  of the member was 0. Nevertheless it should be cleaned up.\n\n   - typo fixes\n\n   - clarify logic to remove potential NULL pointer math\n\n   - remove dead code"\n\n* tag \'libnvdimm-for-6.13\' of git://git.kernel.org/pub/scm/linux/kernel/git/nvdimm/nvdimm:\n  dax: Remove an unused field in struct dax_operations\n  dax: delete a stale directory pmem\n  nvdimm: rectify the illogical code within nd_dax_probe()\n  nvdimm: Correct some typos in comments', 'tree': {'sha': '16a406c9e325d0b9c75f65ca81e8b5615fe6d68a', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/16a406c9e325d0b9c75f65ca81e8b5615fe6d68a'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/78a2cbd809ef834b680f2825d3e4c16ec66f8ffa', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/78a2cbd809ef834b680f2825d3e4c16ec66f8ffa', 'html_url': 'https://github.com/torvalds/linux/commit/78a2cbd809ef834b680f2825d3e4c16ec66f8ffa', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/78a2cbd809ef834b680f2825d3e4c16ec66f8ffa/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'committer': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'parents': [{'sha': '2c22dc1ee3a1d1c50bee5f0f71ebffa86c33e172', 'url': 'https://api.github.com/repos/torvalds/linux/commits/2c22dc1ee3a1d1c50bee5f0f71ebffa86c33e172', 'html_ur ...
# {'sha': '2c22dc1ee3a1d1c50bee5f0f71ebffa86c33e172', 'node_id': 'C_kwDOACN7MtoAKDJjMjJkYzFlZTNhMWQxYzUwYmVlNWYwZjcxZWJmZmE4NmMzM2UxNzI', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T01:31:39Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T01:31:39Z'}, 'message': 'Merge tag \'mailbox-v6.13\' of git://git.kernel.org/pub/scm/linux/kernel/git/jassibrar/mailbox\n\nPull mailbox updates from Jassi Brar:\n "Common:\n   - switch back from remove_new() to remove() callback\n\n  imx:\n   - fix format specifier\n\n  zynqmp:\n   - setup IPI for each child node\n\n  thead:\n   - Add th1520 driver and bindings\n\n  qcom:\n   - add SM8750 and SAR2130p compatibles\n   - fix expected clocks for callbacks\n   - use IRQF_NO_SUSPEND for cpucp\n\n  mtk-cmdq:\n   - switch to __pm_runtime_put_autosuspend()\n   - fix alloc size of clocks\n\n  mpfs:\n   - fix reg properties\n\n  ti-msgmgr:\n   - don\'t use of_match_ptr helper\n   - enable COMPILE_TEST build\n\n  pcc:\n   - consider the PCC_ACK_FLAG\n\n  arm_mhuv2:\n   - fix non-fatal improper reuse of variable"\n\n* tag \'mailbox-v6.13\' of git://git.kernel.org/pub/scm/linux/kernel/git/jassibrar/mailbox:\n  mailbox: pcc: Check before sending MCTP PCC response ACK\n  mailbox: Switch back to struct platform_driver::remove()\n  mailbox: imx: Modify the incorrect format specifier\n  mailbox: arm_mhuv2: clean up loop in get_irq_chan_comb()\n  mailbox: zynqmp: setup IPI for each valid child node\n  dt-bindings: mailbox: Add thead,th1520-mailbox bindings\n  mailbox: Introduce support for T-head TH1520 Mailbox driver\n  mailbox: mtk-cmdq: fix wrong use of sizeof in cmdq_get_clocks()\n  dt-bindings: mailbox: qcom-ipcc: Add SM8750\n  dt-bindings: mailbox: qcom,apcs-kpss-global: correct expected clocks for fallbacks\n  dt-bindings: mailbox: qcom-ipcc: Add SAR2130P compatible\n  mailbox: ti-msgmgr: Allow building under COMPILE_TEST\n  mailbox: ti-msgmgr: Remove use of of_match_ptr() helper\n  mailbox: qcom-cpucp: Mark the irq with IRQF_NO_SUSPEND flag\n  mailbox: mtk-cmdq-mailbox: Switch to __pm_runtime_put_autosuspend()\n  mailbox: mpfs: support new, syscon based, devicetree configuration\n  dt-bindings: mailbox: mpfs: fix reg properties', 'tree': {'sha': '76069e15dcbfaa2f25c8696468f81fdd11d7c906', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/76069e15dcbfaa2f25c8696468f81fdd11d7c906'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/2c22dc1ee3a1d1c50bee5f0f71ebffa86c33e172', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/2c22dc1ee3a1d1c50bee5f0f71ebffa86c33e172', 'html_url': 'https://github.com/torvalds/linux/commit/2c22dc1ee3a1d1c50bee5f0f71ebffa86c33e172', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/2c22dc1ee3a1d1c50bee5f0f71ebffa86c33e172/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public ...
# {'sha': '2d32fba02e0e5b67fb3a4ea51dde80c0db83f1c1', 'node_id': 'C_kwDOACN7MtoAKDJkMzJmYmEwMmUwZTViNjdmYjNhNGVhNTFkZGU4MGMwZGI4M2YxYzE', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T01:24:51Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T01:24:51Z'}, 'message': 'Merge tag \'pinctrl-v6.13-1\' of git://git.kernel.org/pub/scm/linux/kernel/git/linusw/linux-pinctrl\n\nPull pin control updates from Linus Walleij:\n "No core changes this time.\n\n  New drivers:\n\n   - Xlinix Versal pin control driver\n\n   - Ocelot LAN969x pin control driver\n\n   - T-Head TH1520 RISC-V SoC pin control driver\n\n   - Qualcomm SM8750, IPQ5424, QCS8300, SAR2130P and QCS615 SoC pin\n     control drivers\n\n   - Qualcomm SM8750 LPASS (low power audio subsystem) pin control\n     driver\n\n   - Qualcomm PM8937 mixsig IC pin control support, GPIO and MPP\n     (multi-purpose-pin)\n\n   - Samsung Exynos8895 and Exynos9810 SoC pin control driver\n\n   - SpacemiT K1 SoC pin control driver\n\n   - Airhoa EN7581 IC pin control driver\n\n  Improvements:\n\n   - The Renesas subdriver now supports schmitt-trigger and open drain\n     pin configurations if the hardware supports it\n\n   - Support GPIOF and GPIOG banks in the Aspeed G6 SoC\n\n   - Support the DSW community in the Intel Elkhartlake SoC"\n\n* tag \'pinctrl-v6.13-1\' of git://git.kernel.org/pub/scm/linux/kernel/git/linusw/linux-pinctrl: (105 commits)\n  pinctrl: airoha: Use unsigned long for bit search\n  pinctrl: k210: Undef K210_PC_DEFAULT\n  pinctrl: qcom: spmi: fix debugfs drive strength\n  pinctrl: qcom: Add sm8750 pinctrl driver\n  dt-bindings: pinctrl: qcom: Add sm8750 pinctrl\n  pinctrl: cy8c95x0: remove unneeded goto labels\n  pinctrl: cy8c95x0: embed iterator to the for-loop\n  pinctrl: cy8c95x0: Use temporary variable for struct device\n  pinctrl: cy8c95x0: use flexible sleeping in reset function\n  pinctrl: cy8c95x0: switch to using devm_regulator_get_enable()\n  pinctrl: cy8c95x0: Use 2-argument strscpy()\n  dt-bindings: pinctrl: sx150xq: allow gpio line naming\n  pinctrl: single: add marvell,pxa1908-padconf compatible\n  dt-bindings: pinctrl: pinctrl-single: add marvell,pxa1908-padconf compatible\n  dt-bindings: pinctrl: correct typo of description for cv1800\n  pinctrl: qcom: spmi-mpp: Add PM8937 compatible\n  dt-bindings: pinctrl: qcom,pmic-mpp: Document PM8937 compatible\n  pinctrl: qcom-pmic-gpio: add support for PM8937\n  dt-bindings: pinctrl: qcom,pmic-gpio: add PM8937\n  pinctrl: Use of_property_present() for non-boolean properties\n  ...', 'tree': {'sha': 'a430dd7bcb89dc623312ad20731acde995f1368a', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/a430dd7bcb89dc623312ad20731acde995f1368a'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/2d32fba02e0e5b67fb3a4ea51dde80c0db83f1c1', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/2d32fba02e0e5b67fb3a4ea51dde80c0db83f1c1', 'html_url': 'https://github.com/torvalds/linux/commit/2d32fba02e0e5b67fb3a4ea51dde80c0db83f1c1', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/2d32fba02e0e5b67fb3a4ea51dde80c0db83f1c1/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torv ...
# {'sha': '70dbb12e95ec7585c68cb3ceae971688915021e3', 'node_id': 'C_kwDOACN7MtoAKDcwZGJiMTJlOTVlYzc1ODVjNjhjYjNjZWFlOTcxNjg4OTE1MDIxZTM', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T01:15:12Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T01:15:12Z'}, 'message': 'Merge tag \'i2c-for-6.13-part2\' of git://git.kernel.org/pub/scm/linux/kernel/git/wsa/linux\n\nPull more i2c updates from Wolfram Sang:\n "Andi was super busy the last weeks, so this pull requests contains one\n  series (nomadik) and a number of smaller additions which were ready to\n  go but nearly overlooked.\n\n  New feature support:\n\n   - Added support for frequencies up to 3.4 MHz on Nomadik I2C\n\n   - DesignWare now accounts for bus capacitance and clock optimisation\n     (declared as new parameters in the binding) to improve the\n     calculation of signal rise and fall times (t_high and t_low)\n\n  New Hardware support:\n\n   - DWAPB I2C controller on FUJITSU-MONAKA (new ACPI HID)\n\n   - Allwinner A523 (new compatible ID)\n\n   - Mobileye EyeQ6H (new compatible ID)"\n\n* tag \'i2c-for-6.13-part2\' of git://git.kernel.org/pub/scm/linux/kernel/git/wsa/linux:\n  MAINTAINERS: transfer i2c-aspeed maintainership from Brendan to Ryan\n  i2c: designware: determine HS tHIGH and tLOW based on HW parameters\n  dt-bindings: i2c: snps,designware-i2c: declare bus capacitance and clk freq optimized\n  i2c: nomadik: support >=1MHz speed modes\n  i2c: nomadik: fix BRCR computation\n  i2c: nomadik: support Mobileye EyeQ6H I2C controller\n  i2c: nomadik: switch from of_device_is_compatible() to of_match_device()\n  dt-bindings: i2c: nomadik: support 400kHz < clock-frequency <= 3.4MHz\n  dt-bindings: i2c: nomadik: add mobileye,eyeq6h-i2c bindings\n  dt-bindings: i2c: mv64xxx: Add Allwinner A523 compatible string\n  i2c: designware: Add ACPI HID for DWAPB I2C controller on FUJITSU-MONAKA\n  i2c: qup: use generic device property accessors', 'tree': {'sha': 'cf14241e7fffb6679f15fda2b25514bc8a031266', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/cf14241e7fffb6679f15fda2b25514bc8a031266'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/70dbb12e95ec7585c68cb3ceae971688915021e3', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/70dbb12e95ec7585c68cb3ceae971688915021e3', 'html_url': 'https://github.com/torvalds/linux/commit/70dbb12e95ec7585c68cb3ceae971688915021e3', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/70dbb12e95ec7585c68cb3ceae971688915021e3/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'committer': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://g ...
# {'sha': '5d38cb9bee73969125c7818a9f9e3358e0db07d6', 'node_id': 'C_kwDOACN7MtoAKDVkMzhjYjliZWU3Mzk2OTEyNWM3ODE4YTlmOWUzMzU4ZTBkYjA3ZDY', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T01:12:54Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T01:12:54Z'}, 'message': 'Merge tag \'firewire-updates-6.13\' of git://git.kernel.org/pub/scm/linux/kernel/git/ieee1394/linux1394\n\nPull firewire updates from Takashi Sakamoto:\n "A few updates for the 6.13 kernel, including some typo corrections in\n  the software stack and some fixes for tools. Additionally, it includes\n  a change resulting from the deprecation of a kernel API in the PCI\n  subsystem"\n\n* tag \'firewire-updates-6.13\' of git://git.kernel.org/pub/scm/linux/kernel/git/ieee1394/linux1394:\n  tools/firewire: Fix several incorrect format specifiers\n  firewire: ohci: Replace deprecated PCI functions\n  firewire: Correct some typos', 'tree': {'sha': 'fdbe231784006b059ec6e1bb576f5c276a9d9b39', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/fdbe231784006b059ec6e1bb576f5c276a9d9b39'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/5d38cb9bee73969125c7818a9f9e3358e0db07d6', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/5d38cb9bee73969125c7818a9f9e3358e0db07d6', 'html_url': 'https://github.com/torvalds/linux/commit/5d38cb9bee73969125c7818a9f9e3358e0db07d6', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/5d38cb9bee73969125c7818a9f9e3358e0db07d6/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'committer': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'parents': [{'sha': 'e06635e26cd8144eee17e9f256e8fde8aed3ba4f', 'url': 'https://api.github.com/repos/torvalds/linux/commits/e06635e26cd8144eee17e9f256e8fde8aed3ba4f', 'html_url': 'https://github.com/torvalds/linux/commit/e06635e26cd8144eee17e9f256e8fde8aed3ba4f'}, {'sha': '4752e8cde8344c ...
# {'sha': 'e06635e26cd8144eee17e9f256e8fde8aed3ba4f', 'node_id': 'C_kwDOACN7MtoAKGUwNjYzNWUyNmNkODE0NGVlZTE3ZTlmMjU2ZThmZGU4YWVkM2JhNGY', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T00:51:24Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T00:51:24Z'}, 'message': "Merge tag 'slab-for-6.13-v2' of git://git.kernel.org/pub/scm/linux/kernel/git/vbabka/slab\n\nPull slab updates from Vlastimil Babka:\n\n - Add new slab_strict_numa boot parameter to enforce per-object memory\n   policies on top of slab folio policies, for systems where saving cost\n   of remote accesses is more important than minimizing slab allocation\n   overhead (Christoph Lameter)\n\n - Fix for freeptr_offset alignment check being too strict for m68k\n   (Geert Uytterhoeven)\n\n - krealloc() fixes for not violating __GFP_ZERO guarantees on\n   krealloc() when slub_debug (redzone and object tracking) is enabled\n   (Feng Tang)\n\n - Fix a memory leak in case sysfs registration fails for a slab cache,\n   and also no longer fail to create the cache in that case (Hyeonggon\n   Yoo)\n\n - Fix handling of detected consistency problems (due to buggy slab\n   user) with slub_debug enabled, so that it does not cause further list\n   corruption bugs (yuan.gao)\n\n - Code cleanup and kerneldocs polishing (Zhen Lei, Vlastimil Babka)\n\n* tag 'slab-for-6.13-v2' of git://git.kernel.org/pub/scm/linux/kernel/git/vbabka/slab:\n  slab: Fix too strict alignment check in create_cache()\n  mm/slab: Allow cache creation to proceed even if sysfs registration fails\n  mm/slub: Avoid list corruption when removing a slab from the full list\n  mm/slub, kunit: Add testcase for krealloc redzone and zeroing\n  mm/slub: Improve redzone check and zeroing for krealloc()\n  mm/slub: Consider kfence case for get_orig_size()\n  SLUB: Add support for per object memory policies\n  mm, slab: add kerneldocs for common SLAB_ flags\n  mm/slab: remove duplicate check in create_cache()\n  mm/slub: Move krealloc() and related code to slub.c\n  mm/kasan: Don't store metadata inside kmalloc object when slub_debug_orig_size is on", 'tree': {'sha': '24bd832e3098ebf70999a1af6c16087ce4c5995e', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/24bd832e3098ebf70999a1af6c16087ce4c5995e'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/e06635e26cd8144eee17e9f256e8fde8aed3ba4f', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/e06635e26cd8144eee17e9f256e8fde8aed3ba4f', 'html_url': 'https://github.com/torvalds/linux/commit/e06635e26cd8144eee17e9f256e8fde8aed3ba4f', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/e06635e26cd8144eee17e9f256e8fde8aed3ba4f/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'committer': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU= ...
# {'sha': 'f5f4745a7f057b58c9728ee4e2c5d6d79f382fe7', 'node_id': 'C_kwDOACN7MtoAKGY1ZjQ3NDVhN2YwNTdiNThjOTcyOGVlNGUyYzVkNmQ3OWYzODJmZTc', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T00:09:48Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-26T00:09:48Z'}, 'message': 'Merge tag \'mm-nonmm-stable-2024-11-24-02-05\' of git://git.kernel.org/pub/scm/linux/kernel/git/akpm/mm\n\nPull non-MM updates from Andrew Morton:\n\n - The series "resource: A couple of cleanups" from Andy Shevchenko\n   performs some cleanups in the resource management code\n\n - The series "Improve the copy of task comm" from Yafang Shao addresses\n   possible race-induced overflows in the management of\n   task_struct.comm[]\n\n - The series "Remove unnecessary header includes from\n   {tools/}lib/list_sort.c" from Kuan-Wei Chiu adds some cleanups and a\n   small fix to the list_sort library code and to its selftest\n\n - The series "Enhance min heap API with non-inline functions and\n   optimizations" also from Kuan-Wei Chiu optimizes and cleans up the\n   min_heap library code\n\n - The series "nilfs2: Finish folio conversion" from Ryusuke Konishi\n   finishes off nilfs2\'s folioification\n\n - The series "add detect count for hung tasks" from Lance Yang adds\n   more userspace visibility into the hung-task detector\'s activity\n\n - Apart from that, singelton patches in many places - please see the\n   individual changelogs for details\n\n* tag \'mm-nonmm-stable-2024-11-24-02-05\' of git://git.kernel.org/pub/scm/linux/kernel/git/akpm/mm: (71 commits)\n  gdb: lx-symbols: do not error out on monolithic build\n  kernel/reboot: replace sprintf() with sysfs_emit()\n  lib: util_macros_kunit: add kunit test for util_macros.h\n  util_macros.h: fix/rework find_closest() macros\n  Improve consistency of \'#error\' directive messages\n  ocfs2: fix uninitialized value in ocfs2_file_read_iter()\n  hung_task: add docs for hung_task_detect_count\n  hung_task: add detect count for hung tasks\n  dma-buf: use atomic64_inc_return() in dma_buf_getfile()\n  fs/proc/kcore.c: fix coccinelle reported ERROR instances\n  resource: avoid unnecessary resource tree walking in __region_intersects()\n  ocfs2: remove unused errmsg function and table\n  ocfs2: cluster: fix a typo\n  lib/scatterlist: use sg_phys() helper\n  checkpatch: always parse orig_commit in fixes tag\n  nilfs2: convert metadata aops from writepage to writepages\n  nilfs2: convert nilfs_recovery_copy_block() to take a folio\n  nilfs2: convert nilfs_page_count_clean_buffers() to take a folio\n  nilfs2: remove nilfs_writepage\n  nilfs2: convert checkpoint file to be folio-based\n  ...', 'tree': {'sha': '7e5ddce694baa3a0d6c8d7a5b2f59e8778315ee9', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/7e5ddce694baa3a0d6c8d7a5b2f59e8778315ee9'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/f5f4745a7f057b58c9728ee4e2c5d6d79f382fe7', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/f5f4745a7f057b58c9728ee4e2c5d6d79f382fe7', 'html_url': 'https://github.com/torvalds/linux/commit/f5f4745a7f057b58c9728ee4e2c5d6d79f382fe7', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/f5f4745a7f057b58c9728ee4e2c5d6d79f382fe7/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.git ...
# {'sha': '7f4f3b14e8079ecde096bd734af10e30d40c27b7', 'node_id': 'C_kwDOACN7MtoAKDdmNGYzYjE0ZTgwNzllY2RlMDk2YmQ3MzRhZjEwZTMwZDQwYzI3Yjc', 'commit': {'author': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-25T23:44:29Z'}, 'committer': {'name': 'Linus Torvalds', 'email': 'torvalds@linux-foundation.org', 'date': '2024-11-25T23:44:29Z'}, 'message': 'Merge tag \'trace-rust-v6.13\' of git://git.kernel.org/pub/scm/linux/kernel/git/trace/linux-trace\n\nPull rust trace event support from Steven Rostedt:\n "Allow Rust code to have trace events\n\n  Trace events is a popular way to debug what is happening inside the\n  kernel or just to find out what is happening. Rust code is being added\n  to the Linux kernel but it currently does not support the tracing\n  infrastructure. Add support of trace events inside Rust code"\n\n* tag \'trace-rust-v6.13\' of git://git.kernel.org/pub/scm/linux/kernel/git/trace/linux-trace:\n  rust: jump_label: skip formatting generated file\n  jump_label: rust: pass a mut ptr to `static_key_count`\n  samples: rust: fix `rust_print` build making it a combined module\n  rust: add arch_static_branch\n  jump_label: adjust inline asm to be consistent\n  rust: samples: add tracepoint to Rust sample\n  rust: add tracepoint support\n  rust: add static_branch_unlikely for static_key_false', 'tree': {'sha': 'cf36ee62abd3869d8264c0e569f275a4b4d20b92', 'url': 'https://api.github.com/repos/torvalds/linux/git/trees/cf36ee62abd3869d8264c0e569f275a4b4d20b92'}, 'url': 'https://api.github.com/repos/torvalds/linux/git/commits/7f4f3b14e8079ecde096bd734af10e30d40c27b7', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/torvalds/linux/commits/7f4f3b14e8079ecde096bd734af10e30d40c27b7', 'html_url': 'https://github.com/torvalds/linux/commit/7f4f3b14e8079ecde096bd734af10e30d40c27b7', 'comments_url': 'https://api.github.com/repos/torvalds/linux/commits/7f4f3b14e8079ecde096bd734af10e30d40c27b7/comments', 'author': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'committer': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', ...

# %% [markdown]
# ### List contents

# %%
# List contents of this repository
owner = 'ibraym'
repo = 'Data-Source-API-Analyst-Test'
path = ''
contents = g.contents(owner=owner, repo=repo, path=path)

for content in contents:
    print(content)
# Out:
# {'name': 'README.md', 'path': 'README.md', 'sha': '0ad91889ad2a4f2a75bbef8f3642d280a59f2e32', 'size': 3444, 'url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/README.md?ref=master', 'html_url': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/README.md', 'git_url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/0ad91889ad2a4f2a75bbef8f3642d280a59f2e32', 'download_url': 'https://raw.githubusercontent.com/ibraym/Data-Source-API-Analyst-Test/master/README.md', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/README.md?ref=master', 'git': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/0ad91889ad2a4f2a75bbef8f3642d280a59f2e32', 'html': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/README.md'}}
# {'name': 'content', 'path': 'content', 'sha': '2716a8a77c115292e2022aa22b02cf0806693932', 'size': 0, 'url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content?ref=master', 'html_url': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/tree/master/content', 'git_url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/trees/2716a8a77c115292e2022aa22b02cf0806693932', 'download_url': None, 'type': 'dir', '_links': {'self': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content?ref=master', 'git': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/trees/2716a8a77c115292e2022aa22b02cf0806693932', 'html': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/tree/master/content'}}

# %%
# List contents of this repository
owner = 'ibraym'
repo = 'Data-Source-API-Analyst-Test'
path = '/content/docs'
contents = g.contents(owner=owner, repo=repo, path=path)
for content in contents:
    print(content)
# Out:
# {'name': 'auth.md', 'path': 'content/docs/auth.md', 'sha': '1ab51dac3a4f9e6d0d700570cf8f5e734be78538', 'size': 2730, 'url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/auth.md?ref=master', 'html_url': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/auth.md', 'git_url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/1ab51dac3a4f9e6d0d700570cf8f5e734be78538', 'download_url': 'https://raw.githubusercontent.com/ibraym/Data-Source-API-Analyst-Test/master/content/docs/auth.md', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/auth.md?ref=master', 'git': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/1ab51dac3a4f9e6d0d700570cf8f5e734be78538', 'html': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/auth.md'}}
# {'name': 'commits.md', 'path': 'content/docs/commits.md', 'sha': '10d555edfd5417d7745a07ff8a8a11ad3dc396b3', 'size': 1760, 'url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/commits.md?ref=master', 'html_url': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/commits.md', 'git_url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/10d555edfd5417d7745a07ff8a8a11ad3dc396b3', 'download_url': 'https://raw.githubusercontent.com/ibraym/Data-Source-API-Analyst-Test/master/content/docs/commits.md', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/commits.md?ref=master', 'git': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/10d555edfd5417d7745a07ff8a8a11ad3dc396b3', 'html': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/commits.md'}}
# {'name': 'contents.md', 'path': 'content/docs/contents.md', 'sha': 'fd6ee34162472c1dc5833504de0e3122820219eb', 'size': 1599, 'url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/contents.md?ref=master', 'html_url': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/contents.md', 'git_url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/fd6ee34162472c1dc5833504de0e3122820219eb', 'download_url': 'https://raw.githubusercontent.com/ibraym/Data-Source-API-Analyst-Test/master/content/docs/contents.md', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/contents.md?ref=master', 'git': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/fd6ee34162472c1dc5833504de0e3122820219eb', 'html': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/contents.md'}}
# {'name': 'pagination.md', 'path': 'content/docs/pagination.md', 'sha': '7259398862f199e311efcccebfcf40be996d78c8', 'size': 748, 'url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/pagination.md?ref=master', 'html_url': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/pagination.md', 'git_url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/7259398862f199e311efcccebfcf40be996d78c8', 'download_url': 'https://raw.githubusercontent.com/ibraym/Data-Source-API-Analyst-Test/master/content/docs/pagination.md', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/pagination.md?ref=master', 'git': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/7259398862f199e311efcccebfcf40be996d78c8', 'html': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/pagination.md'}}
# {'name': 'rate-limits.md', 'path': 'content/docs/rate-limits.md', 'sha': '6dcf1ac87b62a0d6fa59af11a11aa62a7a25b324', 'size': 5356, 'url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/rate-limits.md?ref=master', 'html_url': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/rate-limits.md', 'git_url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/6dcf1ac87b62a0d6fa59af11a11aa62a7a25b324', 'download_url': 'https://raw.githubusercontent.com/ibraym/Data-Source-API-Analyst-Test/master/content/docs/rate-limits.md', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/rate-limits.md?ref=master', 'git': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/6dcf1ac87b62a0d6fa59af11a11aa62a7a25b324', 'html': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/rate-limits.md'}}
# {'name': 'search_repos.md', 'path': 'content/docs/search_repos.md', 'sha': '44edaa89156767b72d7b5e9fcb6e856c048fac7e', 'size': 2393, 'url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/search_repos.md?ref=master', 'html_url': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/search_repos.md', 'git_url': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/44edaa89156767b72d7b5e9fcb6e856c048fac7e', 'download_url': 'https://raw.githubusercontent.com/ibraym/Data-Source-API-Analyst-Test/master/content/docs/search_repos.md', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/contents/content/docs/search_repos.md?ref=master', 'git': 'https://api.github.com/repos/ibraym/Data-Source-API-Analyst-Test/git/blobs/44edaa89156767b72d7b5e9fcb6e856c048fac7e', 'html': 'https://github.com/ibraym/Data-Source-API-Analyst-Test/blob/master/content/docs/search_repos.md'}}

# %%
# get raw file contents
owner = 'ibraym'
repo = 'Data-Source-API-Analyst-Test'
path = '/README.md'
contents = g.contents(owner=owner, repo=repo, path=path, content_type='raw')
for content in contents:
  print(content)
  break
# Out:
# # Data-Source-API-Analyst-Test
#
# The goal of this repository is to provide an analysis of [GitHub API](https://docs.github.com/en/rest?apiVersion=2022-11-28) including authentication methods, requests logic, pagination, rate limits and error handling.
#
# ## Scope
# Based on the client needs, we are interested in the following endpoints:
#
# 1. [Search Repositories (public)](https://docs.github.com/en/rest/search/search?apiVersion=2022-11-28#search-repositories): \
# [GitHub API](https://docs.github.com/en/rest?apiVersion=2022-11-28) provides the `/search` endpoint that can be used search for specific item. We can search for `commits`, `issues`, `labels`, ...etc. To search for repositories, we should use `/search/repositories`.
#
# 2. [Commits](https://docs.github.com/en/rest/commits/commits?apiVersion=2022-11-28): To get a list of commits of a specific `repo` owned by a specific user `owner` from [GitHub API](https://docs.github.com/en/rest?apiVersion=2022-11-28), we should use `/repos/{owner}/{repo}/commits` endpoint.
#
# 3. [Contents](https://docs.github.com/en/rest/repos/contents?apiVersion=2022-11-28): To get the contents of a file or a directory, referenced by `path` query parameter, of a specific `repo` owned by a specific user `owner` from [GitHub API](https://docs.github.com/en/rest?apiVersion=2022-11-28), we should use `/repos/{owner}/{repo}/contents/{path}` endpoint.
#
# ## Reports
# We researched the documentation to gather information about the required endpoints and how call and get data from the API.
#
# 1. API documentation:
#     1. [Authentication](./content/docs/auth.md)
#     2. [Rate Limits](./content/docs/rate-limits.md)
#     3. [Pagination](./content/docs/pagination.md)
#     1. [Search Repositories (public)](./content/docs/search_repos.md)
#     2. [Commits](./content/docs/commits.md)
#     2. [Contents](./content/docs/contents.md)
#
# 2. Code:
# we prepared a [Jupyter notebook](./content/jupyter_notebook/) that contains the step by step documentation of each function/class we have developed to handle authentication, pagination, rate limits and error handling. It also include some example of how requesting and extracting data from the API.
#
#
# ### Key features of our implementation:
#    - Authentication: Integrates with the Auth class to handle token-based authentication.
#    - Rate Limit Management: Tracks and enforces API rate limits to avoid throttling.
#    - Retry Strategy: Handles retries for network errors and rate-limit responses.
#    - Pagination: Simplifies handling of paginated API responses.
#    - Extensibility: Designed for integration with additional API endpoints and functionalities.
#
# ### Types of Errors Handled
#    - Automatic Retry on Rate Limit Exceeded: The `GithubRetry` class manages retries for both primary and secondary rate limit errors, with intelligent backoff strategies.
#    - Response Validation: The `__check_response` method in `Github` class raises exceptions for HTTP errors (status codes >= 400) and handles both JSON decoding errors and invalid API responses.
#    - Timeouts and Connection Errors: The connection logic includes built-in retries and timeouts.
#    - Customizable Retry and Timeout Logic: The `Github` class allows configuration of retry behavior and request timeouts to customize error handling according to needs.
#    - Detailed Error Messages: The `Github` class provides detailed error messages that include HTTP status codes and response content to help diagnose issues.
